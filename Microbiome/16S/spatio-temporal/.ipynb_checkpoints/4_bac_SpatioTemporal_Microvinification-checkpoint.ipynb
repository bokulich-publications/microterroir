# %% [markdown]
# # 4. Spatio-temporal diversity of MICROVINIFICATION

# %%
#!mkdir /home/lfloerl/cloud/lfloerl/Microterroir/artifacts/16S/lavaux/spatio-temporal/microvinification

# %%
workdir = '/home/lfloerl/cloud/lfloerl/Microterroir/artifacts/16S/lavaux/spatio-temporal/microvinification'
# %cd $workdir
# Out:
# /home/lfloerl/cloud/lfloerl/Microterroir/artifacts/16S/lavaux/spatio-temporal/microvinification

# %%
# %env TMPDIR=/scratch/lfloerl/tmpdata
# Out:
# env: TMPDIR=/scratch/lfloerl/tmpdata

# %%
from qiime2 import Visualization
import qiime2 as q2
from qiime2 import Visualization
from qiime2 import Artifact
from qiime2 import Metadata
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from qiime2.plugins.diversity.visualizers import alpha_group_significance
from qiime2.plugins.diversity.pipelines import core_metrics_phylogenetic

from qiime2.plugins import diversity as q2d

# %matplotlib inline

# %%
md = Metadata.load('/home/lfloerl/microterroir/Microbiome/Metadata/16S_lavaux.tsv')
taxonomy = q2.Artifact.load('/home/lfloerl/cloud/lfloerl/Microterroir/artifacts/16S/taxonomy.qza')

# %%
table = q2.Artifact.load('/home/lfloerl/cloud/lfloerl/Microterroir/artifacts/16S/lavaux/mv_filtered_table.qza')
tree =  q2.Artifact.load('/home/lfloerl/cloud/lfloerl/Microterroir/artifacts/16S/rooted-tree.qza')

# %% [markdown]
# depth of
# * 150: Retained 6’600 (1.99%) features in 44 (46.32%) samples
# * 1000: Retained 15’000 (4.51%) features in 15 (15.79%) samples

# %%
Visualization.load('/home/lfloerl/cloud/lfloerl/Microterroir/artifacts/16S/lavaux/mv_filtered_table.qzv')
# Out:
# <visualization: Visualization uuid: a9dbd3c7-7a5d-4671-9afd-6f3d4ed138bc>

# %% [markdown]
# # Analyse all sample types and years seperately

# %%
# %%bash
#
# # Define the list of sample types and years
# sample_types=('Post-MLF' 'Post-AF' 'MV-must')
# years=('Year2021' 'Year2022' 'Year2023')
#
# # Path to the metadata file
# metadata_file="/home/lfloerl/microterroir/Microbiome/Metadata/16S_lavaux.tsv"
#
# # Create a temporary file to store combinations that exist in the metadata
# valid_combinations="valid_combinations.txt"
#
# # Clear the file if it already exists
# > $valid_combinations
#
# # Check metadata for available combinations
# for samples in "${sample_types[@]}"; do
#   for year in "${years[@]}"; do
#     # Check if the combination exists in the metadata
#     match_count=$(awk -F'\t' -v sample_type="$samples" -v year_cat="$year" \
#       '$0 ~ sample_type && $0 ~ year_cat {count++} END {print count}' "$metadata_file")
#
#     # If the combination is found, log it
#     if [[ $match_count -gt 0 ]]; then
#       echo "$samples,$year" >> $valid_combinations
#     fi
#   done
# done
#
# # Read valid combinations and process only these
# while IFS=, read -r samples year; do
#   echo "Processing $samples in $year"
#
#   # Create directory for the sample type and year and navigate into it
#   dir_name="${samples}_${year}"
#   mkdir -p "./$dir_name"
#   pushd "./$dir_name" > /dev/null
#
#   # Filter table and representative sequences
#   qiime feature-table filter-samples \
#     --i-table /home/lfloerl/cloud/lfloerl/Microterroir/artifacts/16S/lavaux/mv_filtered_table.qza \
#     --m-metadata-file "$metadata_file" \
#     --p-where "[sample_type]='$samples' AND [Year_Cat]='$year'" \
#     --o-filtered-table "mv_${samples}_${year}_filtered_table.qza"
#
#   qiime feature-table filter-seqs \
#     --i-data /home/lfloerl/cloud/lfloerl/Microterroir/artifacts/16S/bac-dada2-single/dada-rep-seqs-220-ee4-fa4.qza \
#     --i-table "mv_${samples}_${year}_filtered_table.qza" \
#     --o-filtered-data "mv_${samples}_${year}_filtered_rep_seqs.qza"
#
#   # Core diversity metrics
#   qiime diversity core-metrics \
#     --i-table "mv_${samples}_${year}_filtered_table.qza" \
#     --p-sampling-depth 150 \
#     --m-metadata-file "$metadata_file" \
#     --p-n-jobs 10 \
#     --p-ignore-missing-samples \
#     --output-dir cm150/
#
#   # Kmer diversity metrics
#   qiime kmerizer core-metrics \
#     --i-sequences "mv_${samples}_${year}_filtered_rep_seqs.qza" \
#     --i-table "mv_${samples}_${year}_filtered_table.qza" \
#     --p-sampling-depth 150 \
#     --m-metadata-file "$metadata_file" \
#     --p-n-jobs auto \
#     --output-dir kmer_cm150/
#
#   # Export all distance matrices for Mantel
#   qiime tools export --input-path cm150/bray_curtis_distance_matrix.qza --output-path cm150/bray_curtis_distance_matrix
#   qiime tools export --input-path cm150/jaccard_distance_matrix.qza --output-path cm150/jaccard_distance_matrix
#   qiime tools export --input-path kmer_cm150/bray_curtis_distance_matrix.qza --output-path kmer_cm150/bray_curtis_distance_matrix
#   qiime tools export --input-path kmer_cm150/jaccard_distance_matrix.qza --output-path kmer_cm150/jaccard_distance_matrix
#
#   # Return to the parent directory
#   popd > /dev/null
# done < $valid_combinations
#
# # Clean up temporary file
# rm $valid_combinations
# Out:
# Processing Post-MLF in Year2021
# Saved FeatureTable[Frequency] to: mv_Post-MLF_Year2021_filtered_table.qza
# Saved FeatureData[Sequence] to: mv_Post-MLF_Year2021_filtered_rep_seqs.qza
# Saved FeatureTable[Frequency] to: cm150/rarefied_table.qza
# Saved SampleData[AlphaDiversity] to: cm150/observed_features_vector.qza
# Saved SampleData[AlphaDiversity] to: cm150/shannon_vector.qza
# Saved SampleData[AlphaDiversity] to: cm150/evenness_vector.qza
# Saved DistanceMatrix to: cm150/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: cm150/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: cm150/jaccard_pcoa_results.qza
# Saved PCoAResults to: cm150/bray_curtis_pcoa_results.qza
# Saved Visualization to: cm150/jaccard_emperor.qzv
# Saved Visualization to: cm150/bray_curtis_emperor.qzv
# Saved FeatureTable[Frequency] to: kmer_cm150/rarefied_table.qza
# Saved FeatureTable[Frequency] to: kmer_cm150/kmer_table.qza
# Saved SampleData[AlphaDiversity] to: kmer_cm150/observed_features_vector.qza
# Saved SampleData[AlphaDiversity] to: kmer_cm150/shannon_vector.qza
# Saved DistanceMatrix to: kmer_cm150/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: kmer_cm150/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: kmer_cm150/jaccard_pcoa_results.qza
# Saved PCoAResults to: kmer_cm150/bray_curtis_pcoa_results.qza
# Saved Visualization to: kmer_cm150/scatterplot.qzv
# Exported cm150/bray_curtis_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory cm150/bray_curtis_distance_matrix
# Exported cm150/jaccard_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory cm150/jaccard_distance_matrix
# Exported kmer_cm150/bray_curtis_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory kmer_cm150/bray_curtis_distance_matrix
# Exported kmer_cm150/jaccard_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory kmer_cm150/jaccard_distance_matrix
# Processing Post-MLF in Year2023
# Saved FeatureTable[Frequency] to: mv_Post-MLF_Year2023_filtered_table.qza
# Saved FeatureData[Sequence] to: mv_Post-MLF_Year2023_filtered_rep_seqs.qza
# Saved FeatureTable[Frequency] to: cm150/rarefied_table.qza
# Saved SampleData[AlphaDiversity] to: cm150/observed_features_vector.qza
# Saved SampleData[AlphaDiversity] to: cm150/shannon_vector.qza
# Saved SampleData[AlphaDiversity] to: cm150/evenness_vector.qza
# Saved DistanceMatrix to: cm150/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: cm150/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: cm150/jaccard_pcoa_results.qza
# Saved PCoAResults to: cm150/bray_curtis_pcoa_results.qza
# Saved Visualization to: cm150/jaccard_emperor.qzv
# Saved Visualization to: cm150/bray_curtis_emperor.qzv
# Saved FeatureTable[Frequency] to: kmer_cm150/rarefied_table.qza
# Saved FeatureTable[Frequency] to: kmer_cm150/kmer_table.qza
# Saved SampleData[AlphaDiversity] to: kmer_cm150/observed_features_vector.qza
# Saved SampleData[AlphaDiversity] to: kmer_cm150/shannon_vector.qza
# Saved DistanceMatrix to: kmer_cm150/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: kmer_cm150/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: kmer_cm150/jaccard_pcoa_results.qza
# Saved PCoAResults to: kmer_cm150/bray_curtis_pcoa_results.qza
# Saved Visualization to: kmer_cm150/scatterplot.qzv
# Exported cm150/bray_curtis_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory cm150/bray_curtis_distance_matrix
# Exported cm150/jaccard_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory cm150/jaccard_distance_matrix
# Exported kmer_cm150/bray_curtis_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory kmer_cm150/bray_curtis_distance_matrix
# Exported kmer_cm150/jaccard_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory kmer_cm150/jaccard_distance_matrix
# Processing Post-AF in Year2021
# Saved FeatureTable[Frequency] to: mv_Post-AF_Year2021_filtered_table.qza
# Saved FeatureData[Sequence] to: mv_Post-AF_Year2021_filtered_rep_seqs.qza
# Saved FeatureTable[Frequency] to: cm150/rarefied_table.qza
# Saved SampleData[AlphaDiversity] to: cm150/observed_features_vector.qza
# Saved SampleData[AlphaDiversity] to: cm150/shannon_vector.qza
# Saved SampleData[AlphaDiversity] to: cm150/evenness_vector.qza
# Saved DistanceMatrix to: cm150/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: cm150/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: cm150/jaccard_pcoa_results.qza
# Saved PCoAResults to: cm150/bray_curtis_pcoa_results.qza
# Saved Visualization to: cm150/jaccard_emperor.qzv
# Saved Visualization to: cm150/bray_curtis_emperor.qzv
# Saved FeatureTable[Frequency] to: kmer_cm150/rarefied_table.qza
# Saved FeatureTable[Frequency] to: kmer_cm150/kmer_table.qza
# Saved SampleData[AlphaDiversity] to: kmer_cm150/observed_features_vector.qza
# Saved SampleData[AlphaDiversity] to: kmer_cm150/shannon_vector.qza
# Saved DistanceMatrix to: kmer_cm150/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: kmer_cm150/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: kmer_cm150/jaccard_pcoa_results.qza
# Saved PCoAResults to: kmer_cm150/bray_curtis_pcoa_results.qza
# Saved Visualization to: kmer_cm150/scatterplot.qzv
# Exported cm150/bray_curtis_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory cm150/bray_curtis_distance_matrix
# Exported cm150/jaccard_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory cm150/jaccard_distance_matrix
# Exported kmer_cm150/bray_curtis_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory kmer_cm150/bray_curtis_distance_matrix
# Exported kmer_cm150/jaccard_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory kmer_cm150/jaccard_distance_matrix
# Processing Post-AF in Year2022
# Saved FeatureTable[Frequency] to: mv_Post-AF_Year2022_filtered_table.qza
# Saved FeatureData[Sequence] to: mv_Post-AF_Year2022_filtered_rep_seqs.qza
# Saved FeatureTable[Frequency] to: cm150/rarefied_table.qza
# Saved SampleData[AlphaDiversity] to: cm150/observed_features_vector.qza
# Saved SampleData[AlphaDiversity] to: cm150/shannon_vector.qza
# Saved SampleData[AlphaDiversity] to: cm150/evenness_vector.qza
# Saved DistanceMatrix to: cm150/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: cm150/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: cm150/jaccard_pcoa_results.qza
# Saved PCoAResults to: cm150/bray_curtis_pcoa_results.qza
# Saved Visualization to: cm150/jaccard_emperor.qzv
# Saved Visualization to: cm150/bray_curtis_emperor.qzv
# Saved FeatureTable[Frequency] to: kmer_cm150/rarefied_table.qza
# Saved FeatureTable[Frequency] to: kmer_cm150/kmer_table.qza
# Saved SampleData[AlphaDiversity] to: kmer_cm150/observed_features_vector.qza
# Saved SampleData[AlphaDiversity] to: kmer_cm150/shannon_vector.qza
# Saved DistanceMatrix to: kmer_cm150/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: kmer_cm150/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: kmer_cm150/jaccard_pcoa_results.qza
# Saved PCoAResults to: kmer_cm150/bray_curtis_pcoa_results.qza
# Saved Visualization to: kmer_cm150/scatterplot.qzv
# Exported cm150/bray_curtis_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory cm150/bray_curtis_distance_matrix
# Exported cm150/jaccard_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory cm150/jaccard_distance_matrix
# Exported kmer_cm150/bray_curtis_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory kmer_cm150/bray_curtis_distance_matrix
# Exported kmer_cm150/jaccard_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory kmer_cm150/jaccard_distance_matrix
# Processing Post-AF in Year2023
# Saved FeatureTable[Frequency] to: mv_Post-AF_Year2023_filtered_table.qza
# Saved FeatureData[Sequence] to: mv_Post-AF_Year2023_filtered_rep_seqs.qza
# Saved FeatureTable[Frequency] to: cm150/rarefied_table.qza
# Saved SampleData[AlphaDiversity] to: cm150/observed_features_vector.qza
# Saved SampleData[AlphaDiversity] to: cm150/shannon_vector.qza
# Saved SampleData[AlphaDiversity] to: cm150/evenness_vector.qza
# Saved DistanceMatrix to: cm150/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: cm150/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: cm150/jaccard_pcoa_results.qza
# Saved PCoAResults to: cm150/bray_curtis_pcoa_results.qza
# Saved Visualization to: cm150/jaccard_emperor.qzv
# Saved Visualization to: cm150/bray_curtis_emperor.qzv
# Saved FeatureTable[Frequency] to: kmer_cm150/rarefied_table.qza
# Saved FeatureTable[Frequency] to: kmer_cm150/kmer_table.qza
# Saved SampleData[AlphaDiversity] to: kmer_cm150/observed_features_vector.qza
# Saved SampleData[AlphaDiversity] to: kmer_cm150/shannon_vector.qza
# Saved DistanceMatrix to: kmer_cm150/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: kmer_cm150/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: kmer_cm150/jaccard_pcoa_results.qza
# Saved PCoAResults to: kmer_cm150/bray_curtis_pcoa_results.qza
# Saved Visualization to: kmer_cm150/scatterplot.qzv
# Exported cm150/bray_curtis_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory cm150/bray_curtis_distance_matrix
# Exported cm150/jaccard_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory cm150/jaccard_distance_matrix
# Exported kmer_cm150/bray_curtis_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory kmer_cm150/bray_curtis_distance_matrix
# Exported kmer_cm150/jaccard_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory kmer_cm150/jaccard_distance_matrix
# Processing MV-must in Year2022
# Saved FeatureTable[Frequency] to: mv_MV-must_Year2022_filtered_table.qza
# Saved FeatureData[Sequence] to: mv_MV-must_Year2022_filtered_rep_seqs.qza
# Saved FeatureTable[Frequency] to: cm150/rarefied_table.qza
# Saved SampleData[AlphaDiversity] to: cm150/observed_features_vector.qza
# Saved SampleData[AlphaDiversity] to: cm150/shannon_vector.qza
# Saved SampleData[AlphaDiversity] to: cm150/evenness_vector.qza
# Saved DistanceMatrix to: cm150/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: cm150/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: cm150/jaccard_pcoa_results.qza
# Saved PCoAResults to: cm150/bray_curtis_pcoa_results.qza
# Saved Visualization to: cm150/jaccard_emperor.qzv
# Saved Visualization to: cm150/bray_curtis_emperor.qzv
# Saved FeatureTable[Frequency] to: kmer_cm150/rarefied_table.qza
# Saved FeatureTable[Frequency] to: kmer_cm150/kmer_table.qza
# Saved SampleData[AlphaDiversity] to: kmer_cm150/observed_features_vector.qza
# Saved SampleData[AlphaDiversity] to: kmer_cm150/shannon_vector.qza
# Saved DistanceMatrix to: kmer_cm150/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: kmer_cm150/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: kmer_cm150/jaccard_pcoa_results.qza
# Saved PCoAResults to: kmer_cm150/bray_curtis_pcoa_results.qza
# Saved Visualization to: kmer_cm150/scatterplot.qzv
# Exported cm150/bray_curtis_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory cm150/bray_curtis_distance_matrix
# Exported cm150/jaccard_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory cm150/jaccard_distance_matrix
# Exported kmer_cm150/bray_curtis_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory kmer_cm150/bray_curtis_distance_matrix
# Exported kmer_cm150/jaccard_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory kmer_cm150/jaccard_distance_matrix
# Processing MV-must in Year2023
# Saved FeatureTable[Frequency] to: mv_MV-must_Year2023_filtered_table.qza
# Saved FeatureData[Sequence] to: mv_MV-must_Year2023_filtered_rep_seqs.qza
# Saved FeatureTable[Frequency] to: cm150/rarefied_table.qza
# Saved SampleData[AlphaDiversity] to: cm150/observed_features_vector.qza
# Saved SampleData[AlphaDiversity] to: cm150/shannon_vector.qza
# Saved SampleData[AlphaDiversity] to: cm150/evenness_vector.qza
# Saved DistanceMatrix to: cm150/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: cm150/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: cm150/jaccard_pcoa_results.qza
# Saved PCoAResults to: cm150/bray_curtis_pcoa_results.qza
# Saved Visualization to: cm150/jaccard_emperor.qzv
# Saved Visualization to: cm150/bray_curtis_emperor.qzv
# Saved FeatureTable[Frequency] to: kmer_cm150/rarefied_table.qza
# Saved FeatureTable[Frequency] to: kmer_cm150/kmer_table.qza
# Saved SampleData[AlphaDiversity] to: kmer_cm150/observed_features_vector.qza
# Saved SampleData[AlphaDiversity] to: kmer_cm150/shannon_vector.qza
# Saved DistanceMatrix to: kmer_cm150/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: kmer_cm150/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: kmer_cm150/jaccard_pcoa_results.qza
# Saved PCoAResults to: kmer_cm150/bray_curtis_pcoa_results.qza
# Saved Visualization to: kmer_cm150/scatterplot.qzv
# Exported cm150/bray_curtis_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory cm150/bray_curtis_distance_matrix
# Exported cm150/jaccard_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory cm150/jaccard_distance_matrix
# Exported kmer_cm150/bray_curtis_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory kmer_cm150/bray_curtis_distance_matrix
# Exported kmer_cm150/jaccard_distance_matrix.qza as DistanceMatrixDirectoryFormat to directory kmer_cm150/jaccard_distance_matrix

# %% [markdown]
# ##  Mantel tests

# %%
# %%bash
# folders=("Post-AF_Year2021" "MV-must_Year2022" "Post-AF_Year2022" "Post-MLF_Year2023" "MV-must_Year2023" "Post-AF_Year2023" "Post-MLF_Year2021")
# geodesic_path='/home/lfloerl/cloud/lfloerl/Microterroir/artifacts/16S/geodesic_distance_16S/distance-matrix.tsv'
#
# for folder in "${folders[@]}"
# do
#     folder_path_1="$folder/cm150"
#     folder_path_2="$folder/kmer_cm150"
#
#     # Call the R script and pass folder paths and geodesic matrix
#     Rscript /home/lfloerl/microterroir/Microbiome/Other_scripts/mantel_test.R "$folder_path_1" "$folder_path_2" "$geodesic_path"
# done
# Out:
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
#                                                      Test Mantel_statistic_r
# 1      Post-AF_Year2021/cm150-bray_curtis_distance_matrix         0.32162214
# 2          Post-AF_Year2021/cm150-jaccard_distance_matrix        -0.05386005
# 3 Post-AF_Year2021/kmer_cm150-bray_curtis_distance_matrix         0.48925045
# 4     Post-AF_Year2021/kmer_cm150-jaccard_distance_matrix         0.08243781
#   Significance
# 1    0.1166667
# 2    0.4861111
# 3    0.1083333
# 4    0.2888889
# Set of permutations < 'minperm'. Generating entire set.
# Set of permutations < 'minperm'. Generating entire set.
# Set of permutations < 'minperm'. Generating entire set.
# Set of permutations < 'minperm'. Generating entire set.
#                                                      Test Mantel_statistic_r
# 1      MV-must_Year2022/cm150-bray_curtis_distance_matrix          0.1013975
# 2          MV-must_Year2022/cm150-jaccard_distance_matrix          0.1012987
# 3 MV-must_Year2022/kmer_cm150-bray_curtis_distance_matrix          0.2896104
# 4     MV-must_Year2022/kmer_cm150-jaccard_distance_matrix          0.1623377
#   Significance
# 1        0.317
# 2        0.371
# 3        0.114
# 4        0.262
#                                                      Test Mantel_statistic_r
# 1      Post-AF_Year2022/cm150-bray_curtis_distance_matrix         0.21233836
# 2          Post-AF_Year2022/cm150-jaccard_distance_matrix        -0.30114470
# 3 Post-AF_Year2022/kmer_cm150-bray_curtis_distance_matrix         0.06872587
# 4     Post-AF_Year2022/kmer_cm150-jaccard_distance_matrix        -0.15966009
#   Significance
# 1        0.217
# 2        0.903
# 3        0.340
# 4        0.773
# Set of permutations < 'minperm'. Generating entire set.
# Set of permutations < 'minperm'. Generating entire set.
# Set of permutations < 'minperm'. Generating entire set.
# Set of permutations < 'minperm'. Generating entire set.
#                                                       Test Mantel_statistic_r
# 1      Post-MLF_Year2023/cm150-bray_curtis_distance_matrix         0.12255635
# 2          Post-MLF_Year2023/cm150-jaccard_distance_matrix         0.06901065
# 3 Post-MLF_Year2023/kmer_cm150-bray_curtis_distance_matrix         0.26493506
# 4     Post-MLF_Year2023/kmer_cm150-jaccard_distance_matrix        -0.15714286
#   Significance
# 1        0.329
# 2        0.347
# 3        0.217
# 4        0.657
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
#                                                      Test Mantel_statistic_r
# 1      MV-must_Year2023/cm150-bray_curtis_distance_matrix         0.06791781
# 2          MV-must_Year2023/cm150-jaccard_distance_matrix         0.24486158
# 3 MV-must_Year2023/kmer_cm150-bray_curtis_distance_matrix        -0.01785714
# 4     MV-must_Year2023/kmer_cm150-jaccard_distance_matrix         0.11071429
#   Significance
# 1    0.3625000
# 2    0.1819444
# 3    0.4652778
# 4    0.3319444
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
#                                                      Test Mantel_statistic_r
# 1      Post-AF_Year2023/cm150-bray_curtis_distance_matrix        -0.02323504
# 2          Post-AF_Year2023/cm150-jaccard_distance_matrix         0.11081327
# 3 Post-AF_Year2023/kmer_cm150-bray_curtis_distance_matrix         0.33571429
# 4     Post-AF_Year2023/kmer_cm150-jaccard_distance_matrix         0.40000000
#   Significance
# 1   0.51944444
# 2   0.38333333
# 3   0.10555556
# 4   0.08472222
# Set of permutations < 'minperm'. Generating entire set.
# Set of permutations < 'minperm'. Generating entire set.
# Set of permutations < 'minperm'. Generating entire set.
# Set of permutations < 'minperm'. Generating entire set.
#                                                       Test Mantel_statistic_r
# 1      Post-MLF_Year2021/cm150-bray_curtis_distance_matrix          0.7827217
# 2          Post-MLF_Year2021/cm150-jaccard_distance_matrix          0.5680861
# 3 Post-MLF_Year2021/kmer_cm150-bray_curtis_distance_matrix          0.8571429
# 4     Post-MLF_Year2021/kmer_cm150-jaccard_distance_matrix          0.3779221
#   Significance
# 1        0.019
# 2        0.040
# 3        0.017
# 4        0.074

# %%
# List of folders to loop through
folders = ["Post-AF_Year2021", "MV-must_Year2022", "Post-AF_Year2022", "Post-MLF_Year2023", 
           "MV-must_Year2023", "Post-AF_Year2023", "Post-MLF_Year2021"]

# Initialize an empty list to store the results
all_results = []

# Loop through each folder and process the results
for folder in folders:
    # Define folder paths for the two subdirectories
    folder_path_2 = os.path.join(folder, "kmer_cm150")
    
    # Define the paths for the mantel_results.tsv files
    mantel_path_2 = os.path.join(folder_path_2, "mantel_results.tsv")
    
    # Check if the mantel results file exists for folder_path_2
    if os.path.exists(mantel_path_2):
        # Read the mantel results file for folder_path_2
        df_2 = pd.read_csv(mantel_path_2, sep="\t")
        # Add the main folder, subfolder, and distance matrix type columns
        df_2['Main_Folder'] = folder
        df_2['Subfolder'] = 'kmer_cm150'
        df_2['Distance_Matrix'] = df_2.apply(
            lambda row: 'bray_curtis_distance_matrix' if 'bray_curtis' in row['Test'] else 'jaccard_distance_matrix',
            axis=1
        )
        all_results.append(df_2)

# Concatenate all the results into a single dataframe
final_results = pd.concat(all_results, ignore_index=True)

# Reorder columns for the final result
final_results = final_results[['Main_Folder', 'Subfolder', 'Distance_Matrix', 'Mantel_statistic_r', 'Significance']]

# Display the final results
final_results
# Out:
#           Main_Folder   Subfolder              Distance_Matrix  \
# 0    Post-AF_Year2021  kmer_cm150  bray_curtis_distance_matrix
# 1    Post-AF_Year2021  kmer_cm150      jaccard_distance_matrix
# 2    Post-AF_Year2021  kmer_cm150  bray_curtis_distance_matrix
# 3    Post-AF_Year2021  kmer_cm150      jaccard_distance_matrix
# 4    MV-must_Year2022  kmer_cm150  bray_curtis_distance_matrix
# 5    MV-must_Year2022  kmer_cm150      jaccard_distance_matrix
# 6    MV-must_Year2022  kmer_cm150  bray_curtis_distance_matrix
# 7    MV-must_Year2022  kmer_cm150      jaccard_distance_matrix
# 8    Post-AF_Year2022  kmer_cm150  bray_curtis_distance_matrix
# 9    Post-AF_Year2022  kmer_cm150      jaccard_distance_matrix
# 10   Post-AF_Year2022  kmer_cm150  bray_curtis_distance_matrix
# 11   Post-AF_Year2022  kmer_cm150      jaccard_distance_matrix
# 12  Post-MLF_Year2023  kmer_cm150  bray_curtis_distance_matrix
# 13  Post-MLF_Year2023  kmer_cm150      jaccard_distance_matrix
# 14  Post-MLF_Year2023  kmer_cm150  bray_curtis_distance_matrix
# 15  Post-MLF_Year2023  kmer_cm150      jaccard_distance_matrix
# 16   MV-must_Year2023  kmer_cm150  bray_curtis_distance_matrix
# 17   MV-must_Year2023  kmer_cm150      jaccard_distance_matrix
# 18   MV-must_Year2023  kmer_cm150  bray_curtis_distance_matrix
# 19   MV-must_Year2023  kmer_cm150      jaccard_distance_matrix
# 20   Post-AF_Year2023  kmer_cm150  bray_curtis_distance_matrix
# 21   Post-AF_Year2023  kmer_cm150      jaccard_distance_matrix
# 22   Post-AF_Year2023  kmer_cm150  bray_curtis_distance_matrix
# 23   Post-AF_Year2023  kmer_cm150      jaccard_distance_matrix
# 24  Post-MLF_Year2021  kmer_cm150  bray_curtis_distance_matrix
# 25  Post-MLF_Year2021  kmer_cm150      jaccard_distance_matrix
# 26  Post-MLF_Year2021  kmer_cm150  bray_curtis_distance_matrix
# 27  Post-MLF_Year2021  kmer_cm150      jaccard_distance_matrix
#
#     Mantel_statistic_r  Significance
# 0             0.321622      0.116667
# 1            -0.053860      0.486111
# 2             0.489250      0.108333
# 3             0.082438      0.288889
# 4             0.101398      0.317000
# 5             0.101299      0.371000
# 6             0.289610      0.114000
# 7             0.162338      0.262000
# 8             0.212338      0.217000
# 9            -0.301145      0.903000
# 10            0.068726      0.340000
# 11           -0.159660      0.773000
# 12            0.122556      0.329000
# 13            0.069011      0.347000
# 14            0.264935      0.217000
# 15           -0.157143      0.657000
# 16            0.067918      0.362500
# 17            0.244862      0.181944
# 18           -0.017857      0.465278
# 19            0.110714      0.331944
# 20           -0.023235      0.519444
# 21            0.110813      0.383333
# 22            0.335714      0.105556
# 23            0.400000      0.084722
# 24            0.782722      0.019000
# 25            0.568086      0.040000
# 26            0.857143      0.017000
# 27            0.377922      0.074000

# %%
folder = 'Post-MLF_Year2021'

dir_prefix = 'cm150'
kmer_dir_prefix = 'kmer_cm150'

geodesic_path='/home/lfloerl/cloud/lfloerl/Microterroir/artifacts/16S/geodesic_distance_16S/distance-matrix.tsv'

# Define paths for distance matrices
bray_curtis_path = os.path.join(folder, dir_prefix, 'bray_curtis_distance_matrix', 'distance-matrix.tsv')
jaccard_path = os.path.join(folder, dir_prefix, 'jaccard_distance_matrix', 'distance-matrix.tsv')
bray_curtis_kmer_path = os.path.join(folder, kmer_dir_prefix, 'bray_curtis_distance_matrix', 'distance-matrix.tsv')
jaccard_kmer_path = os.path.join(folder, kmer_dir_prefix, 'jaccard_distance_matrix', 'distance-matrix.tsv')

metrics = [bray_curtis_path, jaccard_path, bray_curtis_kmer_path, jaccard_kmer_path]

# Labels for the scatter plots
labels = [ ('Geodesic Distance', 'Bray-Curtis Distance'),
    ('Geodesic Distance', 'Jaccard Distance'),
    ('Geodesic Distance', 'Kmer Bray-Curtis Distance'),
    ('Geodesic Distance', 'Kmer Jaccard Distance')]

for metric, (x_label, y_label) in zip(metrics, labels):

    # Load the geodesic distance matrix
    dm1 = pd.read_csv(geodesic_path, sep='\t', index_col=0)

    # Load the other distance matrix
    dm2 = pd.read_csv(metric, sep='\t', index_col=0)

    # Align matrices by common indices
    common_ids = dm1.index.intersection(dm2.index)
    if len(common_ids) == 0:
        raise ValueError(f"No common IDs found between {geodesic_path} and {metric}.")

    dm1 = dm1.loc[common_ids, common_ids]
    dm2 = dm2.loc[common_ids, common_ids]

    # Extract upper triangular values (excluding diagonal)
    dm1_flat = dm1.where(np.triu(np.ones(dm1.shape), k=1).astype(bool)).stack()
    dm2_flat = dm2.where(np.triu(np.ones(dm2.shape), k=1).astype(bool)).stack()

    # Create scatter plot with regression line
    plt.figure(figsize=(6, 4))
    sns.regplot(x=dm1_flat, y=dm2_flat, scatter_kws={'s': 10, 'color': '#56C667FF'}, line_kws={'color': '#3F4788FF'})
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Partial Mantel tests
#
# Run partial Mantel tests with plot properties and control for spatial distance
#
# > **note. we calculate the Pearson (P) and Spearman (S) correlation for the simple Mantel tests**
#
# --> nothing significant

# %%
# !ls
# Out:
# geodesic_distance_16S  MV-must_Year2023  Post-AF_Year2022  Post-MLF_Year2021
# MV-must_Year2022       Post-AF_Year2021  Post-AF_Year2023  Post-MLF_Year2023

# %%
# %%bash
#
# # Define directory prefixes for the different matrices
# dir_prefix='Post-AF_Year2023'
#
# # Define paths for distance matrices
# bray_curtis_path="${dir_prefix}/cm150/bray_curtis_distance_matrix/distance-matrix.tsv"
# jaccard_path="${dir_prefix}/cm150/jaccard_distance_matrix/distance-matrix.tsv"
# bray_curtis_kmer_path="${dir_prefix}/kmer_cm150/bray_curtis_distance_matrix/distance-matrix.tsv"
# jaccard_kmer_path="${dir_prefix}/kmer_cm150/jaccard_distance_matrix/distance-matrix.tsv"
#
# # Define other distance matrices (spatial and plot properties)
# spatial_matrix='/home/lfloerl/cloud/lfloerl/Microterroir/artifacts/16S/geodesic_distance_16S/distance-matrix.tsv'
# plot_properties_matrix='/home/lfloerl/cloud/lfloerl/Microterroir/artifacts/16S/lavaux/spatio-temporal/plot_properties_euclidian_distance_matrix.tsv'
#
# # List of matrices to process
# matrices=("$bray_curtis_path" "$jaccard_path" "$bray_curtis_kmer_path" "$jaccard_kmer_path")
#
# # Prepare an empty list to store results
# result_list=()
#
# # Iterate over the list of matrices
# for matrix in "${matrices[@]}"
# do
#     # Run the R script for each matrix
#     echo "$matrix"
#     Rscript /home/lfloerl/microterroir/Microbiome/Other_scripts/partial_mantel.R "$matrix" "$spatial_matrix" "$plot_properties_matrix"
#     echo "---------------------------------------------------------------------------"
# done
# Out:
# Post-AF_Year2023/cm150/bray_curtis_distance_matrix/distance-matrix.tsv
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
#                                     Test Mantel_statistic_r Significance
# 1               Microbial vs Spatial (P)       -0.230032157    0.8625000
# 2               Microbial vs Spatial (S)       -0.023235041    0.5194444
# 3              Microbial vs Matrix 2 (P)       -0.094842958    0.6555556
# 4              Microbial vs Matrix 2 (S)       -0.001787311    0.4888889
# 5 Micro. vs Matrix 2 (ctrl. for Spatial)       -0.191908377    0.7861111
# 6 Micro. vs Spatial (ctrl. for Matrix 2)       -0.281983853    0.8861111
# ---------------------------------------------------------------------------
# Post-AF_Year2023/cm150/jaccard_distance_matrix/distance-matrix.tsv
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
#                                     Test Mantel_statistic_r Significance
# 1               Microbial vs Spatial (P)         0.03794261    0.4791667
# 2               Microbial vs Spatial (S)         0.11081327    0.3833333
# 3              Microbial vs Matrix 2 (P)        -0.38916219    0.8736111
# 4              Microbial vs Matrix 2 (S)        -0.46827543    0.9305556
# 5 Micro. vs Matrix 2 (ctrl. for Spatial)        -0.40139026    0.8750000
# 6 Micro. vs Spatial (ctrl. for Matrix 2)        -0.11320558    0.6583333
# ---------------------------------------------------------------------------
# Post-AF_Year2023/kmer_cm150/bray_curtis_distance_matrix/distance-matrix.tsv
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
#                                     Test Mantel_statistic_r Significance
# 1               Microbial vs Spatial (P)          0.2532152    0.1402778
# 2               Microbial vs Spatial (S)          0.3357143    0.1055556
# 3              Microbial vs Matrix 2 (P)         -0.2476592    0.8541667
# 4              Microbial vs Matrix 2 (S)         -0.1321429    0.7041667
# 5 Micro. vs Matrix 2 (ctrl. for Spatial)         -0.1757744    0.7652778
# 6 Micro. vs Spatial (ctrl. for Matrix 2)          0.1837654    0.2111111
# ---------------------------------------------------------------------------
# Post-AF_Year2023/kmer_cm150/jaccard_distance_matrix/distance-matrix.tsv
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
# 'nperm' >= set of all permutations: complete enumeration.
# Set of permutations < 'minperm'. Generating entire set.
#                                     Test Mantel_statistic_r Significance
# 1               Microbial vs Spatial (P)         0.20616546   0.30555556
# 2               Microbial vs Spatial (S)         0.40000000   0.08472222
# 3              Microbial vs Matrix 2 (P)        -0.16197003   0.72777778
# 4              Microbial vs Matrix 2 (S)        -0.20714286   0.72500000
# 5 Micro. vs Matrix 2 (ctrl. for Spatial)        -0.09823239   0.67222222
# 6 Micro. vs Spatial (ctrl. for Matrix 2)         0.16185366   0.33888889
# ---------------------------------------------------------------------------

# %% [markdown]
# # PERMANOVA
#
# * geographic: 'Quadrant' and 'Cluster'
# * Plot properties: 'Plot_PCA_kMeans_Cluster'

# %%
# %%bash
#
#
# # Define the list of folders
# folders=("Post-AF_Year2021" "MV-must_Year2022" "Post-AF_Year2022" "Post-MLF_Year2023" "MV-must_Year2023" "Post-AF_Year2023" "Post-MLF_Year2021")
#
# # Path to the metadata file
# metadata_file="/home/lfloerl/microterroir/Microbiome/Metadata/16S_lavaux.tsv"
#
# # Loop over the folders
# for folder in "${folders[@]}"; do
#   echo "Processing $folder"
#
#   # Extract sample type and year from the folder name
#   sample_type=$(echo "$folder" | cut -d'_' -f1)
#   year=$(echo "$folder" | cut -d'_' -f2)
#
#   # Create directory for the sample type and year and navigate into it
#   dir_name="${sample_type}_${year}"
#   pushd "$dir_name" > /dev/null
#
#   # PERMANOVA
#   formula='Quadrant'
#   beta_metrics=('bray_curtis' 'jaccard')
#
#   for m in "${beta_metrics[@]}"; do
#     qiime diversity adonis \
#       --i-distance-matrix "cm150/${m}_distance_matrix.qza" \
#       --m-metadata-file "$metadata_file" \
#       --p-formula "${formula}" \
#       --p-n-jobs 5 \
#       --o-visualization "cm150/adonis_${formula}_${m}.qzv"
#
#     qiime diversity adonis \
#       --i-distance-matrix "kmer_cm150/${m}_distance_matrix.qza" \
#       --m-metadata-file "$metadata_file" \
#       --p-formula "${formula}" \
#       --p-n-jobs 5 \
#       --o-visualization "kmer_cm150/adonis_${formula}_${m}.qzv"
#   done
#
#   # Return to the parent directory
#   popd > /dev/null
# done
# Out:
# Processing Post-AF_Year2021
# Saved Visualization to: cm150/adonis_Quadrant_bray_curtis.qzv
# Saved Visualization to: kmer_cm150/adonis_Quadrant_bray_curtis.qzv
# Saved Visualization to: cm150/adonis_Quadrant_jaccard.qzv
# Saved Visualization to: kmer_cm150/adonis_Quadrant_jaccard.qzv
# Processing MV-must_Year2022
# Saved Visualization to: cm150/adonis_Quadrant_bray_curtis.qzv
# Saved Visualization to: kmer_cm150/adonis_Quadrant_bray_curtis.qzv
# Saved Visualization to: cm150/adonis_Quadrant_jaccard.qzv
# Saved Visualization to: kmer_cm150/adonis_Quadrant_jaccard.qzv
# Processing Post-AF_Year2022
# Saved Visualization to: cm150/adonis_Quadrant_bray_curtis.qzv
# Saved Visualization to: kmer_cm150/adonis_Quadrant_bray_curtis.qzv
# Saved Visualization to: cm150/adonis_Quadrant_jaccard.qzv
# Saved Visualization to: kmer_cm150/adonis_Quadrant_jaccard.qzv
# Processing Post-MLF_Year2023
# Saved Visualization to: cm150/adonis_Quadrant_bray_curtis.qzv
# Saved Visualization to: kmer_cm150/adonis_Quadrant_bray_curtis.qzv
# Saved Visualization to: cm150/adonis_Quadrant_jaccard.qzv
# Saved Visualization to: kmer_cm150/adonis_Quadrant_jaccard.qzv
# Processing MV-must_Year2023
# Saved Visualization to: cm150/adonis_Quadrant_bray_curtis.qzv
# Saved Visualization to: kmer_cm150/adonis_Quadrant_bray_curtis.qzv
# Saved Visualization to: cm150/adonis_Quadrant_jaccard.qzv
# Saved Visualization to: kmer_cm150/adonis_Quadrant_jaccard.qzv
# Processing Post-AF_Year2023
# Saved Visualization to: cm150/adonis_Quadrant_bray_curtis.qzv
# Saved Visualization to: kmer_cm150/adonis_Quadrant_bray_curtis.qzv
# Saved Visualization to: cm150/adonis_Quadrant_jaccard.qzv
# Saved Visualization to: kmer_cm150/adonis_Quadrant_jaccard.qzv
# Processing Post-MLF_Year2021
# Saved Visualization to: cm150/adonis_Quadrant_bray_curtis.qzv
# Saved Visualization to: kmer_cm150/adonis_Quadrant_bray_curtis.qzv
# Saved Visualization to: cm150/adonis_Quadrant_jaccard.qzv
# Saved Visualization to: kmer_cm150/adonis_Quadrant_jaccard.qzv

# %% [markdown]
# * Post-AF_Year2021" "Post-AF_Year2022" "Post-AF_Year2023"
# * "Post-MLF_Year2023" "Post-MLF_Year2021"
# * "MV-must_Year2022" "MV-must_Year2023"

# %%
# Define the folder and formula
folder = "MV-must_Year2023"
formula = "Quadrant"

# %%
Visualization.load(f"{folder}/cm150/adonis_{formula}_bray_curtis.qzv")
# Out:
# <visualization: Visualization uuid: f4ba4c78-b40e-4d00-b048-3e63ef723def>

# %%
Visualization.load(f"{folder}/cm150/adonis_{formula}_jaccard.qzv")
# Out:
# <visualization: Visualization uuid: 734aca0d-df6e-4115-8723-bf738d0d3662>

# %%
Visualization.load(f"{folder}/kmer_cm150/adonis_{formula}_bray_curtis.qzv")
# Out:
# <visualization: Visualization uuid: 0e01c9de-1dc5-4b3c-920c-74ddf7f619ba>

# %%
Visualization.load(f"{folder}/kmer_cm150/adonis_{formula}_jaccard.qzv")
# Out:
# <visualization: Visualization uuid: 60822551-d292-4293-abfa-415ff2e7b6c0>
