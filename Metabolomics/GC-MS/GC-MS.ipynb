# %% [markdown]
# # GC-MS data analysis
#
# Analysis of the GC-MS raw data generated on 13.12.2023 (2023 samples) and 31.1.2024 (2021 and 2022 samples).
#
# --> files were moved from local to cloud (2025-02-10)

# %%
import pandas as pd
import numpy as np
import os

# some statistics 
from scipy.stats import zscore
from skbio import DistanceMatrix
from skbio.stats.distance import permanova, anosim
from itertools import product
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics.pairwise import pairwise_distances
import matplotlib.pyplot as plt
from scipy.stats import f_oneway
from scipy.cluster import hierarchy
from sklearn.ensemble import RandomForestClassifier

# Import from PubChem 
#import requests 
#import pubchempy as pcp

# qiime 2 
import qiime2 as q2
from qiime2 import Visualization
from qiime2 import Artifact, Metadata
from qiime2.plugins.diversity.visualizers import mantel
from qiime2.plugins.diversity.visualizers import adonis

# Visualizations 
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn3

sns.set_style(style="white")

# %matplotlib inline

# %% [markdown]
# # Load raw data
#
# * Of each sample we have 3 measurements, we import all raw data and get the average over each sample.
# * Some compounds were annotated twice, so we just add the values to each other (sometimes a compound is integrated as multiple peaks)
# * Further we rename the columns to make analysis easier.

# %%
# set the directory 
os.chdir('/home/lfloerl/cloud/lfloerl/Microterroir/GC-MS_data')

# %% [markdown]
# ### 2021 / 2022 data

# %%
# load table 
df_2021_2022 = pd.read_csv('rawGCMS_results_2021_2022.csv', index_col=0)
# replace "n.a." to represent scalar missing values
df_2021_2022.replace('n.a.', pd.NA, inplace=True)
# drop CAS column for now 
df_2021_2022.drop(columns=['CAS'], inplace=True)

# first split the dataframes based on the years 
year_2021_columns = [col for col in df_2021_2022.columns if '2021' in col]
year_2022_columns = [col for col in df_2021_2022.columns if '2022' in col]

# Create new DataFrames for each year
df_2021 = df_2021_2022[year_2021_columns].copy()
df_2022 = df_2021_2022[year_2022_columns].copy()

# Extract the last section of each column name
grouped_columns = df_2022.columns.str.rsplit('_', n=1).str[-1]
# Group the DataFrame by the extracted section and calculate the median for each group
df_2022_median = df_2022.apply(pd.to_numeric, errors="coerce").T.groupby(grouped_columns).median().T.groupby(df_2022.index).sum()
# add back the info to the columns 
df_2022_median = df_2022_median.add_prefix('2022_postMLF_')

# Extract the last section of each column name
grouped_columns = df_2021.columns.str.rsplit('_', n=1).str[-1]
# Group the DataFrame by the extracted section and calculate the median for each group
df_2021_median = df_2021.apply(pd.to_numeric, errors="coerce").T.groupby(grouped_columns).median().T.groupby(df_2021.index).sum()

# add back the info to the columns 
df_2021_median = df_2021_median.add_prefix('2021_postMLF_')

# %% [markdown]
# #### Save the 2021 data for a comparison with the Sensory Data

# %%
### TSN normalization
sum_per_profile = df_2021_median.sum(axis=0)
df_2021_median_normalized = df_2021_median.div(sum_per_profile, axis=1)

# transpose and rename 
df_2021_median_T = df_2021_median_normalized.transpose().reset_index(names=['Name'])
df_2021_median_T['Name'] = df_2021_median_T['Name'].apply(lambda x: x.replace('_postMLF', ''))

df_2021_median_T.to_csv('GC-2021-forCorrelation.csv')

# %% [markdown]
# ### 2023 data

# %%
# load table 
df_2023 = pd.read_csv('rawGCMS_results_2023.csv', index_col=0)
# replace "n.a." to represent scalar missing values 
df_2023.replace('n.a.', pd.NA, inplace=True)

# split the dataframes based on sample type 
postMLF_columns = [col for col in df_2023.columns if 'PostMLF' in col]
postAF_columns = [col for col in df_2023.columns if 'PostAF' in col]
must_columns = [col for col in df_2023.columns if 'Must' in col]

# Create new DataFrames for each type
df_2023_postMLF = df_2023[postMLF_columns].copy()
df_2023_postAF = df_2023[postAF_columns].copy()
df_2023_must = df_2023[must_columns].copy()

# Extract the last section of each column name
grouped_columns = df_2023_must.columns.str.rsplit('_', n=1).str[-1]
# Group the DataFrame by the extracted section and calculate the median for each group
df_2023_must_median = df_2023_must.apply(pd.to_numeric, errors="coerce").T.groupby(grouped_columns).median().T.groupby(df_2023_must.index).sum()

# add back the info to the columns 
df_2023_must_median = df_2023_must_median.add_prefix('2023_must_')

grouped_columns = df_2023_postAF.columns.str.rsplit('_', n=1).str[-1]
df_2023_postAF_median = df_2023_postAF.apply(pd.to_numeric, errors="coerce").T.groupby(grouped_columns).median().T.groupby(df_2023_postAF.index).sum()
df_2023_postAF_median = df_2023_postAF_median.add_prefix('2023_postAF_')

grouped_columns = df_2023_postMLF.columns.str.rsplit('_', n=1).str[-1]
df_2023_postMLF_median = df_2023_postMLF.apply(pd.to_numeric, errors="coerce").T.groupby(grouped_columns).median().T.groupby(df_2023_postMLF.index).sum()
df_2023_postMLF_median = df_2023_postMLF_median.add_prefix('2023_postMLF_')

# %% [markdown]
# ### Metadata on the plots

# %%
plots_md = pd.read_csv('/home/lfloerl/microterroir/Microbiome/Metadata/RawMD-Lavaux_plots.csv', index_col=0)
plots_md.head()
# Out:
#       Altitude  Average_slope  Exposition  Min_radiation  Max_radiation  \
# Plot
# 4          450             30  South-West            925            950
# 5          400             30  South-West            900            925
# 9          520             35  South-West            875            900
# 11         490             20       South            925            950
# 12         520             15  South-West            925            950
#
#       Average_radiation Soil_thickness Soil_type Soil_depth    Hydromorphie  \
# Plot
# 4                 937.5       calcosol  Calcaire    100-180  Slightly_redox
# 5                 912.5       calcosol  Calcaire    100-180        no_redox
# 9                 887.5       calcosol  Calcaire    100-180        no_redox
# 11                937.5       calcosol  Calcaire    100-180  Slightly_redox
# 12                937.5    colluviosol  Calcique  above_150  Slightly_redox
#
#       Hydromorphie_code         Geology                   Coordinates  \
# Plot
# 4                     1         Molasse  46°29′55.815″N 6°42′29.007″E
# 5                     0         Molasse  46°29′47.037″N 6°42′31.353″E
# 9                     0         Molasse  46°29′57.936″N 6°42′44.103″E
# 11                    1  Gravel_moraine  46°30′00.818″N 6°42′23.968″E
# 12                    1       Colluvium  46°30′09.426″N 6°42′17.825″E
#
#        Latitude  Longitude
# Plot
# 4     46.498857   6.708072
# 5     46.496407   6.708712
# 9     46.499468   6.712242
# 11    46.500244   6.706655
# 12    46.502628   6.704952

# %% [markdown]
# ## Merge and Normalize
# Normalization according to Total Sum Normalization (TSN)
#
# > TSN is the simplest method for normalizing GC-MS data. It requires dividing the area of each peak in a profile by the total sum of all peaks within that profile such that for the ith peak (xi) of jth profile. (Ref. https://doi.org/10.1002/bies.201700210)
#
#
# --> apply to the different dataframes we are working with

# %%
# MLF data
combined_df_MLF = pd.concat([df_2021_median, df_2022_median, df_2023_postMLF_median], axis=1).dropna(how='all')
# Rename columns by removing "postMLF_" from the names
combined_df_MLF.columns = [col.replace("postMLF_", "") for col in combined_df_MLF.columns]

### TSN normalization
sum_per_profile = combined_df_MLF.sum(axis=0)
# Apply Total Sum Normalization by dividing each value by the sum of its corresponding column
combined_MLF_normalized = combined_df_MLF.div(sum_per_profile, axis=1)

combined_MLF_normalized.to_csv('Artifacts/GC-PostMLF-normalized.csv')

combined_MLF_normalized.head()
# Out:
#                                                     2021_Plot11  2021_Plot12  \
# Name
#  Nonanoic acid                                          0.01397     0.034076
# (5Z)-Octa-1,5-dien-3-ol                                 0.00000     0.000000
# (S)-(+)-6-Methyl-1-octanol                              0.00000     0.000000
# 1,2-Benzenedicarboxylic acid, bis(2-methylpropy...      0.00000     0.000000
# 1,3-Propanediol, diacetate                              0.00000     0.000000
#
#                                                     2021_Plot13  2021_Plot14  \
# Name
#  Nonanoic acid                                         0.003409     0.116630
# (5Z)-Octa-1,5-dien-3-ol                                0.000000     0.002705
# (S)-(+)-6-Methyl-1-octanol                             0.000000     0.000000
# 1,2-Benzenedicarboxylic acid, bis(2-methylpropy...     0.000000     0.000000
# 1,3-Propanediol, diacetate                             0.000000     0.000000
#
#                                                     2021_Plot15  2021_Plot17  \
# Name
#  Nonanoic acid                                         0.078968     0.057038
# (5Z)-Octa-1,5-dien-3-ol                                0.002638     0.002611
# (S)-(+)-6-Methyl-1-octanol                             0.000000     0.000000
# 1,2-Benzenedicarboxylic acid, bis(2-methylpropy...     0.000000     0.000000
# 1,3-Propanediol, diacetate                             0.000000     0.000000
#
#                                                     2021_Plot18  2021_Plot19  \
# Name
#  Nonanoic acid                                         0.105728     0.048042
# (5Z)-Octa-1,5-dien-3-ol                                0.001540     0.000000
# (S)-(+)-6-Methyl-1-octanol                             0.000000     0.000000
# 1,2-Benzenedicarboxylic acid, bis(2-methylpropy...     0.000000     0.000000
# 1,3-Propanediol, diacetate                             0.000000     0.000000
#
#                                                     2021_Plot20  2021_Plot4  \
# Name
#  Nonanoic acid                                         0.084714    0.013101
# (5Z)-Octa-1,5-dien-3-ol                                0.000000    0.000444
# (S)-(+)-6-Methyl-1-octanol                             0.000000    0.000000
# 1,2-Benzenedicarboxylic acid, bis(2-methylpropy...     0.000000    0.000000
# 1,3-Propanediol, diacetate                             0.000000    0.000000
#
#                                                     ...  2023_Plot12  \
# Name                                                ...
#  Nonanoic acid                                      ...          0.0
# (5Z)-Octa-1,5-dien-3-ol                             ...          0.0
# (S)-(+)-6-Methyl-1-octanol                          ...          0.0
# 1,2-Benzenedicarboxylic acid, bis(2-methylpropy...  ...          0.0
# 1,3-Propanediol, diacetate                          ...          0.0
#
#                                                     2023_Plot13  2023_Plot14  \
# Name
#  Nonanoic acid                                              0.0          0.0
# (5Z)-Octa-1,5-dien-3-ol                                     0.0          0.0
# (S)-(+)-6-Methyl-1-octanol                                  0.0          0.0
# 1,2-Benzenedicarboxylic acid, bis(2-methylpropy...          0.0          0.0
# 1,3-Propanediol, diacetate                                  0.0          0.0
#
#                                                     2023_Plot15  2023_Plot17  \
# Name
#  Nonanoic acid                                              0.0          0.0
# (5Z)-Octa-1,5-dien-3-ol                                     0.0          0.0
# (S)-(+)-6-Methyl-1-octanol                                  0.0          0.0
# 1,2-Benzenedicarboxylic acid, bis(2-methylpropy...          0.0          0.0
# 1,3-Propanediol, diacetate                                  0.0          0.0
#
#                                                     2023_Plot19  2023_Plot20  \
# Name
#  Nonanoic acid                                              0.0          0.0
# (5Z)-Octa-1,5-dien-3-ol                                     0.0          0.0
# (S)-(+)-6-Methyl-1-octanol                                  0.0          0.0
# 1,2-Benzenedicarboxylic acid, bis(2-methylpropy...          0.0          0.0
# 1,3-Propanediol, diacetate                                  0.0          0.0
#
#                                                     2023_Plot4  2023_Plot5  \
# Name
#  Nonanoic acid                                             0.0         0.0
# (5Z)-Octa-1,5-dien-3-ol                                    0.0         0.0
# (S)-(+)-6-Methyl-1-octanol                                 0.0         0.0
# 1,2-Benzenedicarboxylic acid, bis(2-methylpropy...         0.0         0.0
# 1,3-Propanediol, diacetate                                 0.0         0.0
#
#                                                     2023_Plot9
# Name
#  Nonanoic acid                                             0.0
# (5Z)-Octa-1,5-dien-3-ol                                    0.0
# (S)-(+)-6-Methyl-1-octanol                                 0.0
# 1,2-Benzenedicarboxylic acid, bis(2-methylpropy...         0.0
# 1,3-Propanediol, diacetate                                 0.0
#
# [5 rows x 32 columns]

# %%
# 2023 data
combined_df_2023 = pd.concat([df_2023_must_median, df_2023_postAF_median, df_2023_postMLF_median], axis=1).dropna(how='all')
combined_df_2023.columns = [col.replace("2023_", "") for col in combined_df_2023.columns]

### TSN normalization
sum_per_profile = combined_df_2023.sum(axis=0)
# Apply Total Sum Normalization by dividing each value by the sum of its corresponding column
combined_2023_normalized = combined_df_2023.div(sum_per_profile, axis=1)

# %%
# ALL data
all_combined_df = pd.concat([df_2023_must_median, df_2023_postAF_median, df_2021_median, df_2022_median, df_2023_postMLF_median], axis=1).dropna(how='all')

### TSN normalization
sum_per_profile = all_combined_df.sum(axis=0)
# Apply Total Sum Normalization by dividing each value by the sum of its corresponding column
all_combined_df_normalized = all_combined_df.div(sum_per_profile, axis=1)

# %% [markdown]
# # Compare the MLF sample from different years

# %% [markdown]
# ### Heatmap MLF samples
#
# #### Normalized

# %%
# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(combined_MLF_normalized, cmap='coolwarm', annot=False)
plt.title('Heatmap with Normalized Values')
plt.xlabel('Samples')
plt.ylabel('TIC')
plt.show()

# %% [markdown]
# #### Z score

# %%
# Calculate z-scores for the DataFrame
z_scores_MLF = (combined_MLF_normalized - combined_MLF_normalized.mean()) / combined_MLF_normalized.std()

# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(z_scores_MLF, cmap='coolwarm', annot=False)
plt.title('Heatmap with Z-score Values')
plt.xlabel('Samples')
plt.ylabel('TIC')
plt.show()

# %%
# Perform hierarchical clustering on the metabolite levels
linkage = hierarchy.linkage(z_scores_MLF.T, method='complete', metric='euclidean')

# Plot the heatmap with hierarchical clustering
plt.figure(figsize=(15, 8))
sns.clustermap(z_scores_MLF, method='complete', metric='euclidean', cmap='coolwarm', col_linkage=linkage, row_cluster=False)
plt.title('Heatmap with Hierarchical Clustering of Metabolite Levels (Z-score)')
plt.xlabel('Samples')
plt.ylabel('Metabolites')
plt.show()

# %% [markdown]
# #### Heatmap Top variable compounds

# %%
# Get the top 10 variable compounds based on their standard deviation
top_20_compounds = z_scores_MLF.std(axis=1).nlargest(20).index
# Select only the top 10 variable compounds
top_20_compounds_df = z_scores_MLF.loc[top_20_compounds]

# Create a heatmap
plt.figure(figsize=(5, 5))
sns.set(rc={'axes.labelsize': 10, 'xtick.labelsize': 8, 'ytick.labelsize': 8})
ax = sns.heatmap(top_20_compounds_df, annot=False, cmap='Blues', cbar=True, linewidths=.5, xticklabels=False)
ax.set(ylabel=None)
#plt.title('Compounds with largest variation between postMLF samples of different years [TIC]')

plt.savefig('Figures/postMLF-Top20var.png', bbox_inches='tight', dpi=1000) 
plt.show()

# %%
# Perform hierarchical clustering on the metabolite levels
#linkage = hierarchy.linkage(z_scores_MLF.T, method='complete', metric='euclidean')

# Get the top 10 variable compounds based on their standard deviation
top_20_compounds = z_scores_MLF.std(axis=1).nlargest(20).index
# Select only the top 10 variable compounds
top_20_compounds_df = z_scores_MLF.loc[top_20_compounds]

sns.set(font_scale=1.1)
# Create a heatmap
plt.figure(figsize=(2, 3))
cluster = sns.clustermap(top_20_compounds_df, method='complete', metric='euclidean', 
                    cmap='Blues', col_linkage=linkage, row_cluster=False, xticklabels=False, dendrogram_ratio=(.2, .1))
cluster.cax.set_position([.05, .2, .03, .45])
#ax.set(ylabel=None)
plt.yticks(fontsize=12)  # Increase y-axis tick fontsize
plt.xticks([])  # Remove x-axis ticks
plt.gca().set_ylabel('')  # Remove y-axis name
plt.gca().set_xlabel('')  # Remove y-axis name
#plt.title('Compounds with largest variation between postMLF samples of different years [TIC]')

plt.savefig('Figures/postMLF-Top20var-cluster.png', bbox_inches='tight', dpi=1000) 
plt.show()

# %%
# Perform hierarchical clustering on the metabolite levels
#linkage = hierarchy.linkage(z_scores_MLF.T, method='complete', metric='euclidean')

# Get the top 10 variable compounds based on their standard deviation
top_20_compounds = z_scores_MLF.std(axis=1).nlargest(20).index
# Select only the top 10 variable compounds
top_20_compounds_df = z_scores_MLF.loc[top_20_compounds]

# Create a heatmap
plt.figure(figsize=(2, 5))
cluster = sns.clustermap(top_20_compounds_df, method='complete', metric='euclidean', 
                    cmap='Blues', col_linkage=linkage, row_cluster=False, xticklabels=True, dendrogram_ratio=(.3, .1))
cluster.cax.set_position([.15, .35, .03, .45])
#ax.set(ylabel=None)
plt.xticks([])  # Remove x-axis ticks
plt.gca().set_ylabel('')  # Remove y-axis name
#plt.title('Compounds with largest variation between postMLF samples of different years [TIC]')

#plt.savefig('Figures/postMLF-Top20var-cluster.png', bbox_inches='tight', dpi=1000) 
plt.show()

# %% [markdown]
# ### PCA Plot of MLF samples

# %%
### Some data prep: 

# drop all rows that contain a NaN because PCA can't handle that 
combined_df_MLF_noNA = combined_MLF_normalized.dropna()

# transpose!
combined_df_MLF_noNA = combined_df_MLF_noNA.transpose()

# add a column that indicates the sample type 
combined_df_MLF_noNA['Year'] = combined_df_MLF_noNA.index.str.split('_').str[0]

# give index a name 
combined_df_MLF_noNA.rename_axis(index='Sample', inplace=True)

# %%
# Instantiate PCA with the max number of components to test --> 12? 
n_components = 12 
pca = PCA(n_components=n_components)

# Fit the PCA to your data
pca.fit(combined_df_MLF_noNA.iloc[:, :-1])

# Plot the explained variance ratio
plt.figure(figsize=(4, 4))
plt.plot(range(1, n_components + 1), np.cumsum(pca.explained_variance_ratio_), marker='o', linestyle='-')
plt.title('Cumulative Explained Variance')
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance')
plt.xticks(range(1, n_components + 1))
plt.grid(True)
plt.show()

# %% [markdown]
# Not sure what number of components to use! --> let's try some different ones!

# %%
# Define the number of components for each plot
n_components_list = [2, 5, 9]

# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 4))  # Adjust the figsize as needed

# Iterate over each number of components
for i, n_components in enumerate(n_components_list):
    # Instantiate PCA
    pca = PCA(n_components=n_components)
    
    # Fit and transform the data
    pca_result = pca.fit_transform(combined_df_MLF_noNA.iloc[:, :-1])
    
    # Create a DataFrame with the principal components
    pca_columns = [f'PC{i}' for i in range(1, n_components + 1)]
    pca_MLF = pd.DataFrame(data=pca_result, columns=pca_columns, index=combined_df_MLF_noNA.index)
    
    # Add the sample type info back
    pca_MLF['Year'] = combined_df_MLF_noNA['Year']
    
    # Compute R^2 of explained variance
    r2 = pca.explained_variance_ratio_.sum()
    
    # Plot the PCA results with observation labels
    sns.scatterplot(data=pca_MLF, x='PC1', y='PC2', hue='Year', palette='ocean', ax=axes[i])
    axes[i].set_xlabel('PC 1')
    axes[i].set_ylabel('PC 2')
    axes[i].set_title(f'components={n_components}, R2={r2:.2f}')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# --> Does not seem to make much difference! Let's proceed with 5

# %%
# Instantiate PCA with the number of components you want
n_components = 5  # You can choose the number of principal components
pca = PCA(n_components=n_components)

# Fit and transform the data
pca_result = pca.fit_transform(combined_df_MLF_noNA.iloc[:, :-1])

# Create a DataFrame with the principal components
pca_columns = [f'PC{i}' for i in range(1, n_components + 1)]
pca_MLF = pd.DataFrame(data=pca_result, columns=pca_columns, index=combined_df_MLF_noNA.index)

# add the sample type info back 
pca_MLF['Year'] = combined_df_MLF_noNA['Year']

# Plot the PCA results with observation labels
plt.figure(figsize=(5, 4))

# make scatterplot and color by sample type 
sns.scatterplot(data=pca_MLF, x='PC1', y='PC2', hue='Year', palette='ocean')


plt.title('n components = 5, R2=0.81')
plt.xlabel('PC 1')
plt.ylabel('PC 2')
#plt.savefig('Figures/PCA-MPF.png', bbox_inches='tight', dpi=1000)
plt.show()

# %%
pca_MLF.dtypes
# Out:
# PC1     float64
# PC2     float64
# PC3     float64
# PC4     float64
# PC5     float64
# Year     object
# dtype: object

# %%
# Define colors 
sns.set_style(style='white')
sample_colors = {'2021': '#56C667FF', 
                 '2022': '#287D8EFF', 
                 '2023': '#481568FF'}

plt.figure(figsize=(3, 3)) 
sns.scatterplot(
    x='PC1', y='PC2',
    data=pca_MLF,
    hue='Year',
    palette=sample_colors,  
    s=60, edgecolor='none', alpha=0.7, legend=False)
plt.xlabel('PC1')
plt.ylabel('PC2')

plt.savefig('/home/lfloerl/cloud/lfloerl/Microterroir/Figures/PostMLF-PCA-GCMS.png', dpi=1000, bbox_inches='tight')  

plt.show()

# %% [markdown]
# ## Diversity analysis

# %%
plots_md = pd.read_csv('/Users/lfloerl/Desktop/MICROTERROIR/Data/Lavaux_plots_md.csv', index_col=0)

# %% [markdown]
# ### Calculate Distance Matrices

# %%
## Modify the metadata to fit the distance matrix 

# Extract the original index (plot numbers)
plot_numbers = plots_md.index
# Initialize an empty list to store duplicated rows
duplicated_rows = []
for plot_number in plot_numbers:
    original_row = plots_md.loc[plot_number]  # Extract the original row
    # Duplicate the row for each year and rename the index accordingly
    for year in [2021, 2022, 2023]:
        new_index = f'{year}_Plot{plot_number}'  # Create the new index name
        duplicated_row = original_row.copy()  # Make a copy of the original row
        duplicated_row.name = new_index  # Rename the index of the copied row
        duplicated_row['Plot'] =  f'Plot{plot_number}'  
        duplicated_row['Year'] = year  # Add a column indicating the year
        duplicated_rows.append(duplicated_row)  # Append the duplicated row to the list
# Concatenate the duplicated rows into a new dataframe
plots_md_duplicated = pd.concat(duplicated_rows, axis=1).T

# %% [markdown]
# Bray Curtis

# %%
# Calculate the Bray-Curtis dissimilarity matrix
distance_matrix = pairwise_distances(combined_MLF_normalized.T, metric='braycurtis')
# Convert the distance matrix to a scikit-bio DistanceMatrix object
BC_distance_matrix = DistanceMatrix(distance_matrix, ids=combined_MLF_normalized.columns)

BC_distance_matrix

# %%
MLF_2021 = combined_MLF_normalized.filter(regex='^2021_')
MLF_2022 = combined_MLF_normalized.filter(regex='^2022_')
MLF_2023 = combined_MLF_normalized.filter(regex='^2023_')

# Calculate the Bray-Curtis dissimilarity matrix
dm_2021 = pairwise_distances(MLF_2021.T, metric='braycurtis')
BC_dm_2021 = DistanceMatrix(dm_2021, ids=MLF_2021.columns)

dm_2022 = pairwise_distances(MLF_2022.T, metric='braycurtis')
BC_dm_2022 = DistanceMatrix(dm_2022, ids=MLF_2022.columns)

dm_2023 = pairwise_distances(MLF_2023.T, metric='braycurtis')
BC_dm_2023 = DistanceMatrix(dm_2023, ids=MLF_2023.columns)

# %% [markdown]
# Jaccard

# %%
# Convert the DataFrame to a numpy array
data_array = combined_MLF_normalized.T.to_numpy()
# Calculate the Jaccard dissimilarity matrix
distance_matrix = pairwise_distances(data_array, metric='jaccard')
# Convert the distance matrix to a scikit-bio DistanceMatrix object
jaccard_distance_matrix = DistanceMatrix(distance_matrix, ids=combined_MLF_normalized.columns)
jaccard_distance_matrix
# Out:
# /Users/lfloerl/miniconda3/envs/qiime2-amplicon-2024.2/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:1776: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ### Mantel: Spatial differences between GC-MS datasets
#
# 1. geodisic distance matrix from the metadata
# 2. matel with distance matrices
#
# --> neither jaccard nor BS have a sign. (p<0.05) effect of the distance between plots and VOCs.

# %%
# saving as tsv file and give the index a name to import it as qiime metadata
plots_md_duplicated.rename_axis(index='id').to_csv('plots_metadata.tsv', sep="\t")

# %% [markdown]
# Note, the geodisic distance matrix was created in the terminal with `qiime2-2021.2`
#
# `qiime coordinates geodesic-distance
#     --m-metadata-file plots_metadata.tsv
#     --p-latitude Latitude
#     --p-longitude Longitude
#     --p-missing-data ignore
#     --o-distance-matrix geodesic_distance_matrix_sample.qza
#     --verbose `

# %%
# load artifacts
jaccard_q2_distance_matrix = Artifact.import_data("DistanceMatrix", jaccard_distance_matrix)
bray_curtis_q2_distance_matrix = Artifact.import_data("DistanceMatrix", BC_distance_matrix)

geodisic_distance_matrix = Artifact.load('/Users/lfloerl/Desktop/MICROTERROIR/Data/Metabolomics/GC-MS/Artifacts/geodesic_distance_matrix_sample.qza')

# %%
# Mantel tests
mantel_res, = mantel(dm1=jaccard_q2_distance_matrix, dm2=geodisic_distance_matrix, intersect_ids=True)
mantel_res.save('Artifacts/Mantel_Jaccard_Geodesic.qzv')

mantel_res, = mantel(dm1=bray_curtis_q2_distance_matrix, dm2=geodisic_distance_matrix, intersect_ids=True)
mantel_res.save('Artifacts/Mantel_BC_Geodesic.qzv')
# Out:
# 'Artifacts/Mantel_BC_Geodesic.qzv'

# %% [markdown]
# Check out different years --> still not significant!

# %%
# load as q2 artifacts
bray_curtis_q2_distance_matrix_2021 = Artifact.import_data("DistanceMatrix", BC_dm_2021)
bray_curtis_q2_distance_matrix_2022 = Artifact.import_data("DistanceMatrix", BC_dm_2022)
bray_curtis_q2_distance_matrix_2023 = Artifact.import_data("DistanceMatrix", BC_dm_2023)

mantel_res, = mantel(dm1=bray_curtis_q2_distance_matrix_2021, dm2=geodisic_distance_matrix, intersect_ids=True)
mantel_res.save('Artifacts/Mantel_BC_Geodesic_2021.qzv')

mantel_res, = mantel(dm1=bray_curtis_q2_distance_matrix_2022, dm2=geodisic_distance_matrix, intersect_ids=True)
mantel_res.save('Artifacts/Mantel_BC_Geodesic_2022.qzv')

mantel_res, = mantel(dm1=bray_curtis_q2_distance_matrix_2023, dm2=geodisic_distance_matrix, intersect_ids=True)
mantel_res.save('Artifacts/Mantel_BC_Geodesic_2023.qzv')
# Out:
# 'Artifacts/Mantel_BC_Geodesic_2023.qzv'

# %%
Visualization.load('Artifacts/Mantel_BC_Geodesic.qzv')
# Out:
# <visualization: Visualization uuid: db0e676a-d7c0-488f-8b07-9aa308a8d97e>

# %% [markdown]
# ### ADONIS PERMANOVA from qiime2
# Only the Year has a significant effect for BC and Jaccard Distance Matrix!

# %%
plots_md_duplicated.columns
# Out:
# Index(['Altitude', 'Average_slope', 'Exposition', 'Min_radiation',
#        'Max_radiation', 'Average_radiation', 'Soil_thickness', 'Soil_type',
#        'Soil_depth', 'Hydromorphie', 'Hydromorphie_code', 'Geology',
#        'Coordinates', 'Longitude', 'Latitude', 'Plot', 'Year'],
#       dtype='object')

# %%
## load metadata
md = Metadata.load('plots_metadata.tsv')

# %%
formula = 'Year + Soil_depth + Soil_type + Average_slope + Exposition + Average_radiation + Soil_thickness + Hydromorphie + Altitude + Geology' 

# Bray Curtis
adonis_res, = adonis(distance_matrix=bray_curtis_q2_distance_matrix, metadata=md,formula=formula)
adonis_res.save('Artifacts/Bray_curtis_ADONIS_plots.qzv')

# Jaccard
adonis_res, = adonis(distance_matrix=jaccard_q2_distance_matrix, metadata=md, formula=formula)
adonis_res.save('Artifacts/Jaccard_ADONIS_plots.qzv')
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: run_adonis.R /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/tmpersy30aa/dm.tsv /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/tmpersy30aa/md.tsv Year + Soil_depth + Soil_type + Average_slope + Exposition + Average_radiation + Soil_thickness + Hydromorphie + Altitude + Geology 999 1 /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/qiime2-temp-5y4krixr/adonis.tsv
#
# R version 4.2.2 (2022-10-31)
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.6-4
# 'adonis' will be deprecated: use 'adonis2' instead
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: run_adonis.R /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/tmp_p5y0xsy/dm.tsv /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/tmp_p5y0xsy/md.tsv Year + Soil_depth + Soil_type + Average_slope + Exposition + Average_radiation + Soil_thickness + Hydromorphie + Altitude + Geology 999 1 /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/qiime2-temp-9t11u_fc/adonis.tsv
#
# R version 4.2.2 (2022-10-31)
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.6-4
# 'adonis' will be deprecated: use 'adonis2' instead
# 'Artifacts/Jaccard_ADONIS_plots.qzv'

# %%
Visualization.load('Artifacts/Bray_curtis_ADONIS.qzv')
# Out:
# <visualization: Visualization uuid: 1f7a24e0-cbc3-408b-95af-670fabb91e17>

# %% [markdown]
# ### Vineyard management, Phenology

# %%
mv_md = pd.read_csv('/Users/lfloerl/Desktop/MICROTERROIR/Data/Vineyard_MV_data.csv', index_col=0)

# rename the index to match the GC MS data
new_index = [f"{year}_Plot{plot}" for plot, year in zip(mv_md.index, mv_md['Year'])]
mv_md.index = new_index
#mv_md.drop(columns=['Year'], inplace=True)

# saving as tsv file and give the index a name to import it as qiime metadata
mv_md.rename_axis(index='id').to_csv('management_metadata.tsv', sep="\t")

# %%
## load metadata
md_management = Metadata.load('management_metadata.tsv')

# %%
mv_md.columns
# Out:
# Index(['Year', 'Phenology_BudBreak', 'Phenology_Flowering', 'Hail_Damage',
#        'Herbicide', 'Mildew', 'Grape_Yield_Estimate', 'Pruning_Weight',
#        'Must_Oechsle', 'Wine_Tartatic_Acid', 'Wine_Malic_Acid', 'Wine_Glucose',
#        'Wine_Fructose', 'Wine_Lactic_Acid', 'Wien_Glycerol',
#        'Wine_Acetic_Acid'],
#       dtype='object')

# %%
formula = 'Year + Phenology_BudBreak + Phenology_Flowering + Hail_Damage + Herbicide + Mildew + Grape_Yield_Estimate + Pruning_Weight + Must_Oechsle + Year:Phenology_BudBreak + Year:Phenology_Flowering + Year:Hail_Damage + Year:Herbicide + Year:Mildew + Year:Grape_Yield_Estimate + Year:Pruning_Weight + Year:Must_Oechsle' 

# Bray Curtis
adonis_res, = adonis(distance_matrix=bray_curtis_q2_distance_matrix, metadata=md_management,formula=formula)
adonis_res.save('Artifacts/Bray_curtis_ADONIS_management.qzv')

# Jaccard
adonis_res, = adonis(distance_matrix=jaccard_q2_distance_matrix, metadata=md_management, formula=formula)
adonis_res.save('Artifacts/Jaccard_ADONIS_management.qzv')
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: run_adonis.R /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/tmp56seo9cq/dm.tsv /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/tmp56seo9cq/md.tsv Year + Phenology_BudBreak + Phenology_Flowering + Hail_Damage + Herbicide + Mildew + Grape_Yield_Estimate + Pruning_Weight + Must_Oechsle + Year:Phenology_BudBreak + Year:Phenology_Flowering + Year:Hail_Damage + Year:Herbicide + Year:Mildew + Year:Grape_Yield_Estimate + Year:Pruning_Weight + Year:Must_Oechsle 999 1 /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/qiime2-temp-5ddn5z34/adonis.tsv
#
# R version 4.2.2 (2022-10-31)
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.6-4
# 'adonis' will be deprecated: use 'adonis2' instead
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: run_adonis.R /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/tmpqytaqyva/dm.tsv /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/tmpqytaqyva/md.tsv Year + Phenology_BudBreak + Phenology_Flowering + Hail_Damage + Herbicide + Mildew + Grape_Yield_Estimate + Pruning_Weight + Must_Oechsle + Year:Phenology_BudBreak + Year:Phenology_Flowering + Year:Hail_Damage + Year:Herbicide + Year:Mildew + Year:Grape_Yield_Estimate + Year:Pruning_Weight + Year:Must_Oechsle 999 1 /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/qiime2-temp-f7fhjgm7/adonis.tsv
#
# R version 4.2.2 (2022-10-31)
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.6-4
# 'adonis' will be deprecated: use 'adonis2' instead
# 'Artifacts/Jaccard_ADONIS_management.qzv'

# %% [markdown]
# the following cells can be deleted

# %%
cols = ['Phenology_BudBreak', 'Phenology_Flowering','Hail_Damage', 'Herbicide', 'Mildew', 'Grape_Yield_Estimate', 'Must_Oechsle']
results_df = pd.DataFrame(columns=['Column', 'p-value'])


for column in cols:
    result = permanova(jaccard_distance_matrix, grouping=mv_md, column=column, permutations=99)
    result_row = {
        'Column': column,
        'p-value': result['p-value']
    }
    # Append the result to the DataFrame
    results_df = results_df.append(result_row, ignore_index=True)

results_df
# Out:
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/2120176559.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/2120176559.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/2120176559.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/2120176559.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/2120176559.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/2120176559.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/2120176559.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
#                  Column  p-value
# 0    Phenology_BudBreak     0.19
# 1   Phenology_Flowering     0.01
# 2           Hail_Damage     0.08
# 3             Herbicide     0.57
# 4                Mildew     0.01
# 5  Grape_Yield_Estimate     0.76
# 6          Must_Oechsle     0.08

# %%
cols = ['Phenology_BudBreak', 'Phenology_Flowering','Hail_Damage', 'Herbicide', 'Mildew', 'Grape_Yield_Estimate', 'Must_Oechsle']

results_df = pd.DataFrame(columns=['Column', 'p-value'])
for column in cols:
    result = permanova(BC_distance_matrix, grouping=mv_md, column=column, permutations=99)
    result_row = {
        'Column': column,
        'p-value': result['p-value']
    }
    # Append the result to the DataFrame
    results_df = results_df.append(result_row, ignore_index=True)

results_df
# Out:
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/4190081435.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/4190081435.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/4190081435.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/4190081435.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/4190081435.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/4190081435.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/4190081435.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
#                  Column  p-value
# 0    Phenology_BudBreak     0.15
# 1   Phenology_Flowering     0.01
# 2           Hail_Damage     0.04
# 3             Herbicide     0.74
# 4                Mildew     0.01
# 5  Grape_Yield_Estimate     0.80
# 6          Must_Oechsle     0.12

# %% [markdown]
# ### Wine chemistry

# %%
mv_md.columns
# Out:
# Index(['Year', 'Phenology_BudBreak', 'Phenology_Flowering', 'Hail_Damage',
#        'Herbicide', 'Mildew', 'Grape_Yield_Estimate', 'Pruning_Weight',
#        'Must_Oechsle', 'Wine_Tartatic_Acid', 'Wine_Malic_Acid', 'Wine_Glucose',
#        'Wine_Fructose', 'Wine_Lactic_Acid', 'Wien_Glycerol',
#        'Wine_Acetic_Acid'],
#       dtype='object')

# %%
formula = 'Wine_Tartatic_Acid + Wine_Malic_Acid + Wine_Glucose + Wine_Lactic_Acid + Wine_Fructose + Wine_Acetic_Acid + Wien_Glycerol ' 

# Bray Curtis
adonis_res, = adonis(distance_matrix=bray_curtis_q2_distance_matrix, metadata=md_management,formula=formula)
adonis_res.save('Artifacts/Bray_curtis_ADONIS_wineChemistry.qzv')

# Jaccard
adonis_res, = adonis(distance_matrix=jaccard_q2_distance_matrix, metadata=md_management, formula=formula)
adonis_res.save('Artifacts/Jaccard_ADONIS_wineChemistry.qzv')
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: run_adonis.R /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/tmptb7smc_g/dm.tsv /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/tmptb7smc_g/md.tsv Wine_Tartatic_Acid + Wine_Malic_Acid + Wine_Glucose + Wine_Lactic_Acid + Wine_Fructose + Wine_Acetic_Acid + Wien_Glycerol  999 1 /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/qiime2-temp-hh_o9xkf/adonis.tsv
#
# R version 4.2.2 (2022-10-31)
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.6-4
# 'adonis' will be deprecated: use 'adonis2' instead
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: run_adonis.R /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/tmpbel8d92o/dm.tsv /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/tmpbel8d92o/md.tsv Wine_Tartatic_Acid + Wine_Malic_Acid + Wine_Glucose + Wine_Lactic_Acid + Wine_Fructose + Wine_Acetic_Acid + Wien_Glycerol  999 1 /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/qiime2-temp-s1wdgwoj/adonis.tsv
#
# R version 4.2.2 (2022-10-31)
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.6-4
# 'adonis' will be deprecated: use 'adonis2' instead
# 'Artifacts/Jaccard_ADONIS_wineChemistry.qzv'

# %%
cols = ['Wine_Tartatic_Acid', 'Wine_Malic_Acid', 'Wine_Glucose',
       'Wine_Fructose', 'Wine_Lactic_Acid', 'Wien_Glycerol', 'Wine_Acetic_Acid']

results_df = pd.DataFrame(columns=['Column', 'p-value'])
for column in cols:
    result = permanova(BC_distance_matrix, grouping=mv_md, column=column, permutations=99)
    result_row = {
        'Column': column,
        'p-value': result['p-value']
    }
    # Append the result to the DataFrame
    results_df = results_df.append(result_row, ignore_index=True)

results_df
# Out:
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/167385561.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/167385561.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/167385561.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/167385561.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/167385561.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/167385561.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/167385561.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
#                Column  p-value
# 0  Wine_Tartatic_Acid     0.03
# 1     Wine_Malic_Acid     0.01
# 2        Wine_Glucose     0.01
# 3       Wine_Fructose     0.01
# 4    Wine_Lactic_Acid     0.16
# 5       Wien_Glycerol     0.06
# 6    Wine_Acetic_Acid     0.03

# %%
cols = ['Wine_Tartatic_Acid', 'Wine_Malic_Acid', 'Wine_Glucose',
       'Wine_Fructose', 'Wine_Lactic_Acid', 'Wien_Glycerol', 'Wine_Acetic_Acid']

results_df = pd.DataFrame(columns=['Column', 'p-value'])
for column in cols:
    result = permanova(jaccard_distance_matrix, grouping=mv_md, column=column, permutations=99)
    result_row = {
        'Column': column,
        'p-value': result['p-value']
    }
    # Append the result to the DataFrame
    results_df = results_df.append(result_row, ignore_index=True)

results_df
# Out:
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/2411306825.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/2411306825.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/2411306825.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/2411306825.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/2411306825.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/2411306825.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
# /var/folders/vs/cscnsm_n1pq4d37fdkylmm940000gq/T/ipykernel_63500/2411306825.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(result_row, ignore_index=True)
#                Column  p-value
# 0  Wine_Tartatic_Acid     0.07
# 1     Wine_Malic_Acid     0.01
# 2        Wine_Glucose     0.01
# 3       Wine_Fructose     0.01
# 4    Wine_Lactic_Acid     0.05
# 5       Wien_Glycerol     0.04
# 6    Wine_Acetic_Acid     0.06

# %% [markdown]
# # Compare 2023 samples
# ## Heatmaps 2023 samples

# %%
# Create a heatmap using Seaborn with a blue color scheme
plt.figure(figsize=(5, 10))
sns.heatmap(combined_2023_normalized, cmap='Blues', annot=False, cbar=True, cbar_kws={'shrink': 0.2}, linewidths=.5)
plt.title('Compare 2023 samples [TIC]')
plt.show()

# %%
# Calculate z-scores for the DataFrame
z_scores_2023 = (combined_2023_normalized - combined_2023_normalized.mean()) / combined_2023_normalized.std()

# Perform hierarchical clustering on the metabolite levels
linkage = hierarchy.linkage(z_scores_2023.T, method='complete', metric='euclidean')

# Plot the heatmap with hierarchical clustering
plt.figure(figsize=(15, 8))
sns.clustermap(z_scores_2023, method='complete', metric='euclidean', cmap='coolwarm', col_linkage=linkage, row_cluster=False)
plt.title('Heatmap with Hierarchical Clustering of Metabolite Levels (Z-score)')
plt.xlabel('Samples')
plt.ylabel('Metabolites')
plt.show()

# %% [markdown]
# #### Heatmap Top variable compounds

# %%
# Calculate row-wise variation and sort by it

combined_df_2023_var = combined_2023_normalized.copy()

# add column for variation along the rows (samples)
combined_df_2023_var['Variation'] = combined_df_2023_var.var(axis=1)
# sort 
combined_df_2023_var_sorted = combined_df_2023_var.sort_values(by='Variation', ascending=False)

# Select the top 10 rows
df_2023_top_var = combined_df_2023_var_sorted.head(20).drop(columns=['Variation'])

# Create a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df_2023_top_var, annot=False, cmap='Blues', cbar=True, linewidths=.5)
plt.title('Compounds with largest variation between 2023 samples [TIC]')
plt.show()

# %% [markdown]
# #### PCA Plot of 2023 samples

# %%
# Instantiate PCA with the number of components you want
n_components = 2  # You can choose the number of principal components
pca = PCA(n_components=n_components)

# drop all rows that contain a NaN because PCA can't handle that 
combined_df_2023_noNA = combined_2023_normalized.dropna()

# transpose!
combined_df_2023_noNA = combined_df_2023_noNA.transpose()

# add a column that indicates the sample type 
combined_df_2023_noNA['Group'] = combined_df_2023_noNA.index.str.split('_').str[0]

# give index a name 
combined_df_2023_noNA.rename_axis(index='Sample', inplace=True)

combined_df_2023_noNA.head()
# Out:
# Name          Nonanoic acid   (5Z)-Octa-1,5-dien-3-ol  \
# Sample
# must_Plot12              0.0                      0.0
# must_Plot13              0.0                      0.0
# must_Plot14              0.0                      0.0
# must_Plot15              0.0                      0.0
# must_Plot17              0.0                      0.0
#
# Name         (S)-(+)-6-Methyl-1-octanol  \
# Sample
# must_Plot12                    0.023094
# must_Plot13                    0.023810
# must_Plot14                    0.029040
# must_Plot15                    0.030131
# must_Plot17                    0.035944
#
# Name         1,2-Benzenedicarboxylic acid, bis(2-methylpropyl) ester  \
# Sample
# must_Plot12                                                0.0
# must_Plot13                                                0.0
# must_Plot14                                                0.0
# must_Plot15                                                0.0
# must_Plot17                                                0.0
#
# Name         1,3-Propanediol, diacetate  1-Butanol  1-Butanol, 2-methyl-  \
# Sample
# must_Plot12                         0.0        0.0              0.173333
# must_Plot13                         0.0        0.0              0.045006
# must_Plot14                         0.0        0.0              0.096433
# must_Plot15                         0.0        0.0              0.000000
# must_Plot17                         0.0        0.0              0.063050
#
# Name         1-Butanol, 3,3-dimethyl-  1-Butanol, 3-methyl-  \
# Sample
# must_Plot12                       0.0              0.000000
# must_Plot13                       0.0              0.031253
# must_Plot14                       0.0              0.017183
# must_Plot15                       0.0              0.041421
# must_Plot17                       0.0              0.024654
#
# Name         1-Butanol, 3-methyl-, acetate  ...  \
# Sample                                      ...
# must_Plot12                            0.0  ...
# must_Plot13                            0.0  ...
# must_Plot14                            0.0  ...
# must_Plot15                            0.0  ...
# must_Plot17                            0.0  ...
#
# Name         Propanoic acid, 2-hydroxy-, ethyl ester, (S)-  \
# Sample
# must_Plot12                                            0.0
# must_Plot13                                            0.0
# must_Plot14                                            0.0
# must_Plot15                                            0.0
# must_Plot17                                            0.0
#
# Name         Propanoic acid, 2-methyl-  Tetradecane  \
# Sample
# must_Plot12                   0.025442     0.002750
# must_Plot13                   0.026071     0.002604
# must_Plot14                   0.027100     0.002702
# must_Plot15                   0.032614     0.002547
# must_Plot17                   0.038510     0.002857
#
# Name         Undecanoic acid, ethyl ester  \
# Sample
# must_Plot12                           0.0
# must_Plot13                           0.0
# must_Plot14                           0.0
# must_Plot15                           0.0
# must_Plot17                           0.0
#
# Name         VARAMOL 106 YLBICYCLO[2HYLENE]R]ETHYLPHENYL ESTER]]  \
# Sample
# must_Plot12                                                0.0
# must_Plot13                                                0.0
# must_Plot14                                                0.0
# must_Plot15                                                0.0
# must_Plot17                                                0.0
#
# Name         trans-Geranylacetone  trans-Nerolidol  ß-Citronellol  \
# Sample
# must_Plot12              0.001377              0.0       0.002818
# must_Plot13              0.001301              0.0       0.002239
# must_Plot14              0.001542              0.0       0.001950
# must_Plot15              0.001775              0.0       0.002007
# must_Plot17              0.001909              0.0       0.002141
#
# Name         ß-Damascenone  Group
# Sample
# must_Plot12            0.0   must
# must_Plot13            0.0   must
# must_Plot14            0.0   must
# must_Plot15            0.0   must
# must_Plot17            0.0   must
#
# [5 rows x 152 columns]

# %%
# Fit and transform the data
pca_result = pca.fit_transform(combined_df_2023_noNA.iloc[:, :-1])

# Create a DataFrame with the principal components
pca_columns = [f'PC{i}' for i in range(1, n_components + 1)]
pca_2023 = pd.DataFrame(data=pca_result, columns=pca_columns, index=combined_df_2023_noNA.index)

# add the sample type info back 
pca_2023['Group'] = combined_df_2023_noNA['Group']

# Plot the PCA results with observation labels
plt.figure(figsize=(6, 4))

# make scatterplot and color by sample type 
sns.scatterplot(data=pca_2023, x='PC1', y='PC2', hue='Group', palette='colorblind')

# add the lables 
#for observation, pc1, pc2 in zip(combined_df_2023_noNA.index, pca_2023['PC1'], pca_2023['PC2']): plt.text(pc1, pc2, observation)

plt.title('PCA Plot of 2023 samples')
plt.xlabel('PC 1')
plt.ylabel('PC 2')
plt.show()

# %% [markdown]
# # Compare all samples

# %% [markdown]
# ### PCA

# %%
# Instantiate PCA with the number of components you want
n_components = 2  # You can choose the number of principal components
pca = PCA(n_components=n_components)

# drop all rows that contain a NaN because PCA can't handle that 
combined_df_noNA = all_combined_df_normalized.dropna()
# transpose!
combined_df_noNA = combined_df_noNA.transpose()
# add a column that indicates the sample type and year!
combined_df_noNA['Group'] = combined_df_noNA.index.str.split('_').str[:2].str.join('_')
# give index a name 
combined_df_noNA.rename_axis(index='Sample', inplace=True)

# %%
# Fit and transform the data
pca_result = pca.fit_transform(combined_df_noNA.iloc[:, :-1])

# Create a DataFrame with the principal components
pca_columns = [f'PC{i}' for i in range(1, n_components + 1)]
pca_2023 = pd.DataFrame(data=pca_result, columns=pca_columns, index=combined_df_noNA.index)

# add the sample type info back 
pca_2023['Group'] = combined_df_noNA['Group']

# Plot the PCA results with observation labels
plt.figure(figsize=(6, 4))

# make scatterplot and color by sample type 
sns.scatterplot(data=pca_2023, x='PC1', y='PC2', hue='Group', palette='dark')

# add the lables 
#for observation, pc1, pc2 in zip(combined_df_2023_noNA.index, pca_2023['PC1'], pca_2023['PC2']): plt.text(pc1, pc2, observation)

plt.title('PCA Plot of all samples')
plt.xlabel('PC 1')
plt.ylabel('PC 2')
plt.show()

# %% [markdown]
# ## Diversity analysis (all)

# %% [markdown]
# ### Shannon Diversity Index

# %%
def shannon_diversity(column):
    """Calculate Shannon Diversity for a single column."""
    counts = column.value_counts()  # Count occurrences of each unique value
    total_count = counts.sum()
    probabilities = counts / total_count
    shannon_entropy = -np.sum(probabilities * np.log(probabilities))
    return shannon_entropy

def shannon_diversity_df(df):
    """Calculate Shannon Diversity for each column in a DataFrame."""
    shannon_diversity_values = {}
    for column in df.columns:
        shannon_diversity_values[column] = shannon_diversity(df[column])
    return pd.Series(shannon_diversity_values)

# %%
shannon_diversity_results = pd.DataFrame(shannon_diversity_df(all_combined_df_normalized)).reset_index()
shannon_diversity_results.columns = ["Names", "Values"]

# %%
# make cols for year and sample type! 
shannon_diversity_results['Sample Type'] = shannon_diversity_results['Names'].apply(lambda x: x.split('_')[1])
shannon_diversity_results['Year'] = shannon_diversity_results['Names'].apply(lambda x: x.split('_')[0])

# %%
# Plot box plots
plt.figure(figsize=(5, 4))
sns.boxplot(data=shannon_diversity_results, x='Sample Type', y='Values', hue='Year', dodge=True)
plt.title('Shannon Diversity indices by Sample Type and Year')
plt.xlabel('Sample Type')
plt.ylabel('Values')
plt.legend(title='Year')
plt.tight_layout() 
plt.show()

# %%
# Plot box plots
plt.figure(figsize=(5, 4))
sns.boxplot(data=shannon_diversity_results, x='Year', y='Values', hue='Sample Type', dodge=True)
plt.title('Shannon Diversity indices by Sample Type and Year')
plt.xlabel('Year')
plt.ylabel('Values')
plt.legend(title='Sample Type')
plt.tight_layout() 
plt.show()

# %% [markdown]
# ### Richness

# %%
def richness(df):
    """Calculate richness (number of unique values) for each column in a DataFrame."""
    return df.apply(lambda x: x.nunique())

# %%
richness_df = pd.DataFrame(richness(all_combined_df_normalized)).reset_index()
richness_df.columns = ["Names", "Richness"]

# make cols for year and sample type! 
richness_df['Sample Type'] = richness_df['Names'].apply(lambda x: x.split('_')[1])
richness_df['Year'] = richness_df['Names'].apply(lambda x: x.split('_')[0])

# %% [markdown]
# #### Check if statistically significant differences

# %%
richness_grouped = richness_df.groupby(['Year', 'Sample Type'])['Richness']

# Extract values for each group
group_postMLF_2023_values = richness_grouped.get_group(('2023', 'postMLF'))
group_postMLF_2022_values = richness_grouped.get_group(('2022', 'postMLF'))
group_postMLF_2021_values = richness_grouped.get_group(('2021', 'postMLF'))

# Perform ANOVA tests
print('RICHNESS postMLF ANOVAS')
anova_result = f_oneway(group_postMLF_2023_values, group_postMLF_2022_values)
print("ANOVA 2023 vs 2022 p-value:", anova_result.pvalue)
anova_result = f_oneway(group_postMLF_2023_values, group_postMLF_2021_values)
print("ANOVA 2023 vs 2021 p-value:", anova_result.pvalue)
anova_result = f_oneway(group_postMLF_2022_values, group_postMLF_2021_values)
print("ANOVA 2022 vs 2021 p-value:", anova_result.pvalue)


print('\n RICHNESS 2023 ANOVAS')
group_must_2023_values = richness_grouped.get_group(('2023', 'must'))
group_postAF_2023_values = richness_grouped.get_group(('2023', 'postAF'))

anova_result = f_oneway(group_must_2023_values, group_postAF_2023_values)
print("ANOVA 2023 must vs postAF p-value:", anova_result.pvalue)
anova_result = f_oneway(group_must_2023_values, group_postMLF_2023_values)
print("ANOVA 2023 must vs postMLF p-value:", anova_result.pvalue)
anova_result = f_oneway(group_postAF_2023_values, group_postMLF_2023_values)
print("ANOVA 2023 postAF vs postMLF p-value:", anova_result.pvalue)
# Out:
# RICHNESS postMLF ANOVAS
# ANOVA 2023 vs 2022 p-value: 0.00024669959065453924
# ANOVA 2023 vs 2021 p-value: 8.240851861621958e-07
# ANOVA 2022 vs 2021 p-value: 0.00046537953231202327
#
#  RICHNESS 2023 ANOVAS
# ANOVA 2023 must vs postAF p-value: 0.0003759617148885569
# ANOVA 2023 must vs postMLF p-value: 0.006525973640884719
# ANOVA 2023 postAF vs postMLF p-value: 0.0917658126785716

# %% [markdown]
# #### Box Plots

# %%
# Plot box plots
plt.figure(figsize=(5, 4))
sns.boxplot(data=richness_df, x='Year', y='Richness', hue='Sample Type', dodge=True, palette="Blues")
#plt.title('Richness by Sample Type and Year')
plt.xlabel('Year')
plt.ylabel('Richness')
plt.legend(title='Sample Type')
plt.tight_layout()
plt.savefig('Figures/Richness-BoxPlot.png', bbox_inches='tight', dpi=1000)
plt.show()

# %%
# Plot box plots
sns.set_style(style="white")
plt.figure(figsize=(5, 4))
sns.boxplot(data=richness_df, x='Sample Type', y='Richness', hue='Year', dodge=True)
plt.title('Richness by Sample Type and Year')
plt.xlabel('Sample Type')
plt.ylabel('Values')
plt.legend(title='Year')
plt.tight_layout() 
plt.show()
