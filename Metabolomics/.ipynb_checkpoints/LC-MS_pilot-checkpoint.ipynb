# %% [markdown]
# # LC-MS pilot @FGCZ
#
# Analysis of the LC-MS pilot on Microvinification samples run by FGCZ in march 2024.

# %%
import pandas as pd
import numpy as np
import os

# Visualizations 
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
from matplotlib.sankey import Sankey

# %matplotlib inline

# %%
#!pip install openpyxl
#!pip install matplotlib-venn

# %% [markdown]
# ## Load raw data

# %%
# set the directory 
os.chdir('/Users/lfloerl/Desktop/MICROTERROIR/Metabolomics/LC-MS/FGCZ pilot')

# %%
# load table 
df_neg_all = pd.read_excel('p32837_o33656_neg_features_ALL.xlsx')
df_pos_all = pd.read_excel('p32837_o33656_pos_features_ALL.xlsx')

df_pos_MS2 = pd.read_excel('p32837_o33656_pos_features_MS2.xlsx')
df_neg_MS2 = pd.read_excel('p32837_o33656_neg_features_MS2.xlsx')

# %%
df_neg_all.head()
# Out:
#    Tags  Checked                             Name    Formula  \
# 0   NaN    False                  L-Tartaric acid   C4 H6 O6
# 1   NaN    False                        D-Glucose  C6 H12 O6
# 2   NaN    False            3-Isopropylmalic acid  C7 H12 O5
# 3   NaN    False  Oxoglutaric acid; LC-tDDA; CE10   C5 H6 O5
# 4   NaN    False                      CITRIC ACID   C6 H8 O7
#
#   Annot. Source: Predicted Compositions Annot. Source: mzCloud Search  \
# 0                            Full match                 Partial match
# 1                            Full match                 Partial match
# 2                            Full match                    No results
# 3                            Full match                 Partial match
# 4                            Full match                 Partial match
#
#   Annot. Source: mzVault Search Annot. Source: ChemSpider Search  \
# 0                    Full match                    Partial match
# 1                    Full match                    Partial match
# 2                    Full match                  Not the top hit
# 3                    Full match                    Partial match
# 4                    Full match                    Partial match
#
#   Annot. Source: MassList Search  Annot. DeltaMass [ppm]  ...  \
# 0                     Full match                   -0.87  ...
# 1                     Full match                   -0.52  ...
# 2                     Full match                   -0.54  ...
# 3                     Full match                   -0.85  ...
# 4                     Full match                   -0.61  ...
#
#    Adj. P-value: (Must) / (MLF)  Peak Rating: 2_FS_neg_1.raw (F21)  \
# 0                  3.069539e-05                                8.9
# 1                  5.948837e-07                                NaN
# 2                  7.274725e-13                                8.9
# 3                  2.457335e-06                                9.2
# 4                  2.457335e-06                                NaN
#
#    Peak Rating: 2_FS_neg_2.raw (F22)  Peak Rating: 2_FS_neg_3.raw (F23)  \
# 0                                9.2                               10.0
# 1                                NaN                                NaN
# 2                                8.5                                8.1
# 3                                8.9                                9.2
# 4                                NaN                                NaN
#
#    Peak Rating: 3_FS_neg_1.raw (F34)  Peak Rating: 3_FS_neg_2.raw (F35)  \
# 0                                8.9                                8.9
# 1                                NaN                                NaN
# 2                                8.9                                8.5
# 3                                8.9                                9.6
# 4                                NaN                                NaN
#
#    Peak Rating: 3_FS_neg_3.raw (F36)  Peak Rating: 1_FS_neg_1.raw (F8)  \
# 0                                8.9                               9.6
# 1                                NaN                               6.3
# 2                                8.5                               NaN
# 3                                9.2                               NaN
# 4                                NaN                               9.2
#
#    Peak Rating: 1_FS_neg_2.raw (F9)  Peak Rating: 1_FS_neg_3.raw (F10)
# 0                               8.9                                8.9
# 1                               6.7                                6.3
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               9.6                                9.2
#
# [5 rows x 81 columns]

# %%
print("All positive mode", df_pos_all.shape)
print("All negative mode", df_neg_all.shape)
# Out:
# All positive mode (5024, 86)
# All negative mode (3579, 81)

# %% [markdown]
# ## Venn Diagram of overlapping IDs

# %%
# Extracting sets of names
IDs_pos = set(df_pos_all['Name'])
IDs_neg = set(df_neg_all['Name'])

# Creating the Venn diagram
venn2(subsets=[IDs_pos, IDs_neg], set_labels=('Positive Mode', 'Negative Mode'),
      set_colors=('#006994', '#2CA58D', '#7FB3D5'), alpha=0.5)

# Display the plot
plt.title('Venn Diagram of all features')
plt.show()

# %%
# Extracting sets of names
IDs_pos_MS2 = set(df_pos_MS2['Name'])
IDs_neg_MS2 = set(df_neg_MS2['Name'])

# Creating the Venn diagram
venn2(subsets=[IDs_pos_MS2, IDs_neg_MS2], set_labels=('Positive Mode', 'Negative Mode'),
      set_colors=('skyblue', 'lightgreen'))

# Display the plot
plt.title('Venn Diagram of all MS2 identified features')
plt.show()

# %% [markdown]
# ### Heatmaps
# not sure how FGCZ created these (what transformation / normalization) because these look quite different...

# %%
df_pos_all.columns
# Out:
# Index(['Name', 'Formula', 'Annot. Source: Predicted Compositions',
#        'Annot. Source: mzCloud Search', 'Annot. Source: mzVault Search',
#        'Annot. Source: ChemSpider Search', 'Annot. Source: MassList Search',
#        'Annot. DeltaMass [Da]', 'Annot. DeltaMass [ppm]', 'Calc. MW', 'm/z',
#        'RT [min]', 'Area (Max.)', '# ChemSpider Results', '# mzCloud Results',
#        '# mzVault Results', 'mzCloud Best Match',
#        'mzCloud Best Match Confidence', 'mzVault Best Match',
#        'mzVault Library Match: Bamba lab 34 lipid mediators library stepped NCE 10 30 45',
#        'mzVault Library Match: Bamba lab 598 polar metabolites stepped NCE 10 30 45',
#        'mzVault Library Match: LipidBlast-VS68-Pos',
#        'mzVault Library Match: NIST_msms_metabolites',
#        'mzVault Library Match: Creation of a Plant Metabolite Spectral Library for Untargeted and targeted Metabolomics',
#        'mzVault Library Match: MoNA_All_Nov2023', 'Class Coverage: d18_1',
#        'Class Coverage: d18Cer', 'Class Coverage: GalNAc',
#        'Class Coverage: GalNAc-H2O', 'Class Coverage: NeuAc-H2O',
#        'Class Coverage: PC_SM',
#        'Class Coverage: Phosphatidylcholine Compound Class',
#        'Mass List Match: Arita Lab 6549 Flavonoid Structure Database',
#        'Mass List Match: Endogenous Metabolites database 4400 compounds',
#        'Mass List Match: Mass_List_Lipids_All_Splash_CD3_3',
#        'Mass List Match: LipidMaps Structure Database 2023-01-11',
#        'Mass List Match: Natural Products Atlas 2021_08', 'MS2',
#        'Neutral Losses', 'Reference Ion', 'Area: 2_DDA_pos_1.raw (F15)',
#        'Area: 2_FS_pos_1.raw (F24)', 'Area: 2_FS_pos_2.raw (F25)',
#        'Area: 2_FS_pos_3.raw (F26)', 'Area: 3_DDA_pos_1.raw (F28)',
#        'Area: 3_FS_pos_1.raw (F37)', 'Area: 3_FS_pos_2.raw (F38)',
#        'Area: 3_FS_pos_3.raw (F39)', 'Area: 1_DDA_pos_1.raw (F2)',
#        'Area: 1_FS_pos_1.raw (F11)', 'Area: 1_FS_pos_2.raw (F12)',
#        'Area: 1_FS_pos_3.raw (F13)', 'Group Area: AF', 'Group Area: MLF',
#        'Group Area: Must', 'Group CV [%]: AF', 'Group CV [%]: MLF',
#        'Group CV [%]: Must', 'Ratio: (MLF) / (AF)', 'Ratio: (Must) / (AF)',
#        'Ratio: (AF) / (MLF)', 'Ratio: (Must) / (MLF)',
#        'Log2 Fold Change: (MLF) / (AF)', 'Log2 Fold Change: (Must) / (AF)',
#        'Log2 Fold Change: (AF) / (MLF)', 'Log2 Fold Change: (Must) / (MLF)',
#        'P-value: (MLF) / (AF)', 'P-value: (Must) / (AF)',
#        'P-value: (AF) / (MLF)', 'P-value: (Must) / (MLF)',
#        'Adj. P-value: (MLF) / (AF)', 'Adj. P-value: (Must) / (AF)',
#        'Adj. P-value: (AF) / (MLF)', 'Adj. P-value: (Must) / (MLF)',
#        'Peak Rating: 2_DDA_pos_1.raw (F15)',
#        'Peak Rating: 2_FS_pos_1.raw (F24)',
#        'Peak Rating: 2_FS_pos_2.raw (F25)',
#        'Peak Rating: 2_FS_pos_3.raw (F26)',
#        'Peak Rating: 3_DDA_pos_1.raw (F28)',
#        'Peak Rating: 3_FS_pos_1.raw (F37)',
#        'Peak Rating: 3_FS_pos_2.raw (F38)',
#        'Peak Rating: 3_FS_pos_3.raw (F39)',
#        'Peak Rating: 1_DDA_pos_1.raw (F2)',
#        'Peak Rating: 1_FS_pos_1.raw (F11)',
#        'Peak Rating: 1_FS_pos_2.raw (F12)',
#        'Peak Rating: 1_FS_pos_3.raw (F13)'],
#       dtype='object')

# %%
df_pos_data = df_pos_all[['Area: 2_FS_pos_1.raw (F24)', 'Area: 2_FS_pos_2.raw (F25)',
       'Area: 2_FS_pos_3.raw (F26)', 'Area: 3_FS_pos_1.raw (F37)', 'Area: 3_FS_pos_2.raw (F38)',
       'Area: 3_FS_pos_3.raw (F39)', 'Area: 1_FS_pos_1.raw (F11)', 'Area: 1_FS_pos_2.raw (F12)',
       'Area: 1_FS_pos_3.raw (F13)']]

# %%
df_pos_data = df_pos_data.rename(columns={
    'Area: 2_FS_pos_1.raw (F24)' : 'AF_Rep1',
    'Area: 2_FS_pos_2.raw (F25)' : 'AF_Rep2',
    'Area: 2_FS_pos_3.raw (F26)' : 'AF_Rep3',
    'Area: 3_FS_pos_1.raw (F37)' : 'MF_Rep1', 
    'Area: 3_FS_pos_2.raw (F38)' : 'MF_Rep2',
    'Area: 3_FS_pos_3.raw (F39)' : 'MF_Rep3', 
    'Area: 1_FS_pos_1.raw (F11)' : 'Must_Rep1',
    'Area: 1_FS_pos_2.raw (F12)' : 'Must_Rep2',
    'Area: 1_FS_pos_3.raw (F13)' : 'Must_Rep3'},  
    errors="raise")

# %%
# Create heatmap
plt.figure(figsize=(6, 6))
ax = sns.heatmap(np.log10(df_pos_data), cmap='viridis', annot=None)
plt.title('Heatmap log 10 transformed POS raw data')

#plt.xlabel('Samples')
#plt.ylabel('Features')

# Remove y-axis tick labels
ax.set_yticklabels([])
ax.tick_params(axis='y', which='both', length=0)

plt.show()
